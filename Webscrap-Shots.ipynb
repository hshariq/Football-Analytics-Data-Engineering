# %%
print('j')
# Out:
# j

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/147.9 kB 435.7 kB/s eta 0:00:01
#    ---------- ---------------------------- 41.0/147.9 kB 393.8 kB/s eta 0:00:01
#    --------------------- ----------------- 81.9/147.9 kB 573.4 kB/s eta 0:00:01
#    ------------------------------- ------ 122.9/147.9 kB 602.4 kB/s eta 0:00:01
#    -------------------------------------- 147.9/147.9 kB 588.4 kB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.12.3 bs4-0.0.2 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# Error processing line 1 of C:\Users\hamza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib-3.6.3-py3.10-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site.py", line 186, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 568, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\hamza\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests 
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.sofascore.com/girona-fc-real-sociedad/zgbsoKj#id:11369489',
                        headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0'})

# %%
response.status_code
# Out:
# 200

# %%
import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"ec2fea3514"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
}

# response = requests.get('https://api.sofascore.com/api/v1/event/11369489/shotmap', headers=headers)

# %%
#get current date
import datetime
headers['If-Modified-Since']= datetime.datetime.now().isoformat()

# %%
response = requests.get('https://api.sofascore.com/api/v1/event/11369489/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
shots = response.json()

# %%
shots
# Out:
# {'shotmap': [{'player': {'name': 'Yangel Herrera',
#     'slug': 'yangel-herrera',
#     'shortName': 'Y. Herrera',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 2374,
#     'id': 839585,
#     'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'},
#      'shortNameTranslation': {'ar': 'ي. هيريرا'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 9.4, 'y': 42.4, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 52.2, 'z': 19},
#    'blockCoordinates': {'x': 7.5, 'y': 43.5, 'z': 0},
#    'xg': 0.024029621854424,
#    'id': 2464622,
#    'time': 90,
#    'addedTime': 7,
#    'timeSeconds': 5760,
#    'draw': {'start': {'x': 42.4, 'y': 9.4},
#     'block': {'x': 43.5, 'y': 7.5},
#     'end': {'x': 47.8, 'y': 0},
#     'goal': {'x': 47.8, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 540,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Yangel Herrera',
#     'slug': 'yangel-herrera',
#     'shortName': 'Y. Herrera',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 2374,
#     'id': 839585,
#     'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'},
#      'shortNameTranslation': {'ar': 'ي. هيريرا'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 13.6, 'y': 59, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 52.8, 'z': 19},
#    'blockCoordinates': {'x': 10.7, 'y': 56.5, 'z': 0},
#    'xg': 0.057783525437117,
#    'id': 2464621,
#    'time': 90,
#    'addedTime': 6,
#    'timeSeconds': 5738,
#    'draw': {'start': {'x': 59, 'y': 13.6},
#     'block': {'x': 56.5, 'y': 10.7},
#     'end': {'x': 47.2, 'y': 0},
#     'goal': {'x': 47.2, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 562,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Valery Fernández',
#     'slug': 'valery-fernandez',
#     'shortName': 'V. Fernández',
#     'position': 'D',
#     'jerseyNumber': '11',
#     'userCount': 359,
#     'id': 962378,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فرنانديز ، فاليري'},
#      'shortNameTranslation': {'ar': 'ف. ، فاليري'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 9.4, 'y': 47.9, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 40.3, 'z': 18.1},
#    'xg': 0.19038042426109,
#    'id': 2464620,
#    'time': 90,
#    'addedTime': 5,
#    'timeSeconds': 5661,
#    'draw': {'start': {'x': 47.9, 'y': 9.4},
#     'end': {'x': 59.7, 'y': 0},
#     'goal': {'x': 59.7, 'y': 81.9}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 639,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Daley Blind',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'daley-blind',
#     'shortName': 'D. Blind',
#     'position': 'D',
#     'jerseyNumber': '23',
#     'userCount': 3770,
#     'id': 44864,
#     'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'},
#      'shortNameTranslation': {'ar': 'د. بلايند'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 27.6, 'y': 61.1, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.9, 'z': 19},
#    'blockCoordinates': {'x': 19.5, 'y': 58.5, 'z': 0},
#    'xg': 0.033932123333216,
#    'id': 2464617,
#    'time': 90,
#    'addedTime': 4,
#    'timeSeconds': 5621,
#    'draw': {'start': {'x': 61.1, 'y': 27.6},
#     'block': {'x': 58.5, 'y': 19.5},
#     'end': {'x': 52.1, 'y': 0},
#     'goal': {'x': 52.1, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 679,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Jon Pacheco',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'jon-pacheco',
#     'shortName': 'J. Pacheco',
#     'position': 'D',
#     'jerseyNumber': '20',
#     'userCount': 243,
#     'id': 934383,
#     'fieldTranslations': {'nameTranslation': {'ar': 'جون باتشيكو'},
#      'shortNameTranslation': {'ar': 'ج. باتشيكو'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 10.6, 'y': 44.9, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 52.8, 'z': 19},
#    'blockCoordinates': {'x': 7.1, 'y': 45.7, 'z': 0},
#    'xg': 0.069741666316986,
#    'id': 2464608,
#    'time': 90,
#    'timeSeconds': 5353,
#    'draw': {'start': {'x': 44.9, 'y': 10.6},
#     'block': {'x': 45.7, 'y': 7.1},
#     'end': {'x': 47.2, 'y': 0},
#     'goal': {'x': 47.2, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 47,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Yangel Herrera',
#     'slug': 'yangel-herrera',
#     'shortName': 'Y. Herrera',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 2374,
#     'id': 839585,
#     'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'},
#      'shortNameTranslation': {'ar': 'ي. هيريرا'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 9.5, 'y': 66.4, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 46.9, 'z': 3.2},
#    'blockCoordinates': {'x': 1.8, 'y': 52, 'z': 0},
#    'xg': 0.043857332319021,
#    'xgot': 0.1397,
#    'id': 2464590,
#    'time': 83,
#    'timeSeconds': 4934,
#    'draw': {'start': {'x': 66.4, 'y': 9.5},
#     'block': {'x': 52, 'y': 1.8},
#     'end': {'x': 53.1, 'y': 0},
#     'goal': {'x': 53.1, 'y': 96.8}},
#    'reversedPeriodTime': 8,
#    'reversedPeriodTimeSeconds': 466,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Igor Zubeldia',
#     'slug': 'igor-zubeldia',
#     'shortName': 'I. Zubeldia',
#     'position': 'D',
#     'jerseyNumber': '5',
#     'userCount': 663,
#     'id': 838159,
#     'fieldTranslations': {'nameTranslation': {'ar': 'زوبيلديا, إيجور'},
#      'shortNameTranslation': {'ar': 'إ. زوبيلديا'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 7.1, 'y': 45.1, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 0.8, 'z': 11.1},
#    'blockCoordinates': {'x': 12.1, 'y': 88.3, 'z': 0},
#    'xg': 0.10778696089983,
#    'id': 2464584,
#    'time': 77,
#    'timeSeconds': 4585,
#    'draw': {'start': {'x': 45.1, 'y': 7.1},
#     'block': {'x': 88.3, 'y': 12.1},
#     'end': {'x': 99.2, 'y': 0},
#     'goal': {'x': 99.2, 'y': 88.9}},
#    'reversedPeriodTime': 14,
#    'reversedPeriodTimeSeconds': 815,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Brais Méndez',
#     'slug': 'brais-mendez',
#     'shortName': 'B. Méndez',
#     'position': 'M',
#     'jerseyNumber': '23',
#     'userCount': 2003,
#     'id': 845385,
#     'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'},
#      'shortNameTranslation': {'ar': 'ب. منديز'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 10.5, 'y': 59.1, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 50.3, 'z': 34.2},
#    'blockCoordinates': {'x': 0.7, 'y': 51.1, 'z': 0},
#    'xg': 0.1620799601078,
#    'xgot': 0.0776,
#    'id': 2464553,
#    'time': 72,
#    'timeSeconds': 4316,
#    'draw': {'start': {'x': 59.1, 'y': 10.5},
#     'block': {'x': 51.1, 'y': 0.7},
#     'end': {'x': 49.7, 'y': 0},
#     'goal': {'x': 49.7, 'y': 65.8}},
#    'reversedPeriodTime': 19,
#    'reversedPeriodTimeSeconds': 1084,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Jon Aramburu',
#     'firstName': 'Jon Aramburu',
#     'lastName': '',
#     'slug': 'jon-aramburu',
#     'shortName': 'J. Aramburu',
#     'position': 'M',
#     'jerseyNumber': '39',
#     'userCount': 357,
#     'id': 1116388},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 21.6, 'y': 76.9, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.2, 'z': 77.8},
#    'xg': 0.017356714233756,
#    'id': 2464547,
#    'time': 70,
#    'timeSeconds': 4143,
#    'draw': {'start': {'x': 76.9, 'y': 21.6},
#     'end': {'x': 52.8, 'y': 0},
#     'goal': {'x': 52.8, 'y': 22.2}},
#    'reversedPeriodTime': 21,
#    'reversedPeriodTimeSeconds': 1257,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Aleix García',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'aleix-garcia',
#     'shortName': 'A. García',
#     'position': 'M',
#     'jerseyNumber': '14',
#     'userCount': 2899,
#     'id': 796047,
#     'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'},
#      'shortNameTranslation': {'ar': 'أ. جارسيا'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 21.5, 'y': 41.3, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.6, 'z': 19},
#    'blockCoordinates': {'x': 15, 'y': 44, 'z': 0},
#    'xg': 0.096756622195244,
#    'id': 2464529,
#    'time': 65,
#    'timeSeconds': 3864,
#    'draw': {'start': {'x': 41.3, 'y': 21.5},
#     'block': {'x': 44, 'y': 15},
#     'end': {'x': 50.4, 'y': 0},
#     'goal': {'x': 50.4, 'y': 81}},
#    'reversedPeriodTime': 26,
#    'reversedPeriodTimeSeconds': 1536,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Mikel Oyarzabal',
#     'slug': 'mikel-oyarzabal',
#     'shortName': 'M. Oyarzabal',
#     'position': 'F',
#     'jerseyNumber': '10',
#     'userCount': 4513,
#     'id': 823622,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أويارزابال, ميكيل'},
#      'shortNameTranslation': {'ar': 'م. أويارزابال'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 21.2, 'y': 43.6, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.6, 'z': 19},
#    'blockCoordinates': {'x': 18.1, 'y': 44.6, 'z': 0},
#    'xg': 0.03315020725131,
#    'id': 2464512,
#    'time': 62,
#    'timeSeconds': 3668,
#    'draw': {'start': {'x': 43.6, 'y': 21.2},
#     'block': {'x': 44.6, 'y': 18.1},
#     'end': {'x': 50.4, 'y': 0},
#     'goal': {'x': 50.4, 'y': 81}},
#    'reversedPeriodTime': 29,
#    'reversedPeriodTimeSeconds': 1732,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Ander Barrenetxea',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'ander-barrenetxea',
#     'shortName': 'A. Barrenetxea',
#     'position': 'F',
#     'jerseyNumber': '7',
#     'userCount': 1249,
#     'id': 966862,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بارنيتكسيا, أندر'},
#      'shortNameTranslation': {'ar': 'أ. بارنيتكسيا'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 20.4, 'y': 68.2, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.5, 'z': 19},
#    'blockCoordinates': {'x': 17.7, 'y': 65.9, 'z': 0},
#    'xg': 0.03002449683845,
#    'id': 2464493,
#    'time': 57,
#    'timeSeconds': 3411,
#    'draw': {'start': {'x': 68.2, 'y': 20.4},
#     'block': {'x': 65.9, 'y': 17.7},
#     'end': {'x': 50.5, 'y': 0},
#     'goal': {'x': 50.5, 'y': 81}},
#    'reversedPeriodTime': 34,
#    'reversedPeriodTimeSeconds': 1989,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Sheraldo Becker',
#     'slug': 'sheraldo-becker',
#     'shortName': 'S. Becker',
#     'position': 'F',
#     'jerseyNumber': '11',
#     'userCount': 1613,
#     'id': 352544,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شيرالدو بيكر'},
#      'shortNameTranslation': {'ar': 'ش. بيكر'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 18.1, 'y': 70.7, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'close-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 42.9, 'z': 2.8},
#    'xg': 0.04538705945015,
#    'id': 2464477,
#    'time': 50,
#    'timeSeconds': 2998,
#    'draw': {'start': {'x': 70.7, 'y': 18.1},
#     'end': {'x': 57.1, 'y': 0},
#     'goal': {'x': 57.1, 'y': 97.2}},
#    'reversedPeriodTime': 41,
#    'reversedPeriodTimeSeconds': 2402,
#    'incidentType': 'shot'},
#   {'player': {'name': 'André Silva',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'andre-silva',
#     'shortName': 'A. Silva',
#     'position': 'F',
#     'jerseyNumber': '21',
#     'userCount': 6823,
#     'id': 190159,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'},
#      'shortNameTranslation': {'ar': 'أ. سيلفا'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 22.3, 'y': 46.7, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'close-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 56.8, 'z': 5.6},
#    'xg': 0.023845247924328,
#    'id': 2464472,
#    'time': 49,
#    'timeSeconds': 2918,
#    'draw': {'start': {'x': 46.7, 'y': 22.3},
#     'end': {'x': 43.2, 'y': 0},
#     'goal': {'x': 43.2, 'y': 94.4}},
#    'reversedPeriodTime': 42,
#    'reversedPeriodTimeSeconds': 2482,
#    'incidentType': 'shot'},
#   {'player': {'name': 'André Silva',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'andre-silva',
#     'shortName': 'A. Silva',
#     'position': 'F',
#     'jerseyNumber': '21',
#     'userCount': 6823,
#     'id': 190159,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'},
#      'shortNameTranslation': {'ar': 'أ. سيلفا'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 22.2, 'y': 54.3, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 51.9, 'z': 1.3},
#    'blockCoordinates': {'x': 0.5, 'y': 50.7, 'z': 0},
#    'xg': 0.043737564235926,
#    'xgot': 0.1055,
#    'id': 2464338,
#    'time': 31,
#    'timeSeconds': 1813,
#    'draw': {'start': {'x': 54.3, 'y': 22.2},
#     'block': {'x': 50.7, 'y': 0.5},
#     'end': {'x': 48.1, 'y': 0},
#     'goal': {'x': 48.1, 'y': 98.7}},
#    'reversedPeriodTime': 15,
#    'reversedPeriodTimeSeconds': 887,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Sávio',
#     'firstName': 'Sávio',
#     'lastName': '',
#     'slug': 'savio',
#     'shortName': 'Sávio',
#     'position': 'M',
#     'jerseyNumber': '16',
#     'userCount': 5820,
#     'id': 1046795,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سافيو'},
#      'shortNameTranslation': {'ar': 'سافيو'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 15, 'y': 30.4, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 34.6, 'z': 26.4},
#    'xg': 0.034219179302454,
#    'id': 2464337,
#    'time': 29,
#    'timeSeconds': 1734,
#    'draw': {'start': {'x': 30.4, 'y': 15},
#     'end': {'x': 65.4, 'y': 0},
#     'goal': {'x': 65.4, 'y': 73.6}},
#    'reversedPeriodTime': 17,
#    'reversedPeriodTimeSeconds': 966,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Miguel Gutiérrez',
#     'slug': 'miguel-gutierrez',
#     'shortName': 'M. Gutiérrez',
#     'position': 'D',
#     'jerseyNumber': '3',
#     'userCount': 2754,
#     'id': 908716,
#     'fieldTranslations': {'nameTranslation': {'ar': 'جوتيريز ، ميغيل'},
#      'shortNameTranslation': {'ar': 'ج. ، ميغيل'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 18.8, 'y': 51.9, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 51.7, 'z': 19},
#    'blockCoordinates': {'x': 11.8, 'y': 50.5, 'z': 0},
#    'xg': 0.055620305240154,
#    'id': 2464319,
#    'time': 23,
#    'timeSeconds': 1331,
#    'draw': {'start': {'x': 51.9, 'y': 18.8},
#     'block': {'x': 50.5, 'y': 11.8},
#     'end': {'x': 48.3, 'y': 0},
#     'goal': {'x': 48.3, 'y': 81}},
#    'reversedPeriodTime': 23,
#    'reversedPeriodTimeSeconds': 1369,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Aleix García',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'aleix-garcia',
#     'shortName': 'A. García',
#     'position': 'M',
#     'jerseyNumber': '14',
#     'userCount': 2899,
#     'id': 796047,
#     'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'},
#      'shortNameTranslation': {'ar': 'أ. جارسيا'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 13.8, 'y': 59.9, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 48.7, 'z': 8.9},
#    'blockCoordinates': {'x': 1.2, 'y': 50.7, 'z': 0},
#    'xg': 0.068754702806473,
#    'xgot': 0.0398,
#    'id': 2464318,
#    'time': 23,
#    'timeSeconds': 1329,
#    'draw': {'start': {'x': 59.9, 'y': 13.8},
#     'block': {'x': 50.7, 'y': 1.2},
#     'end': {'x': 51.3, 'y': 0},
#     'goal': {'x': 51.3, 'y': 91.1}},
#    'reversedPeriodTime': 23,
#    'reversedPeriodTimeSeconds': 1371,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Daley Blind',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'daley-blind',
#     'shortName': 'D. Blind',
#     'position': 'D',
#     'jerseyNumber': '23',
#     'userCount': 3770,
#     'id': 44864,
#     'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'},
#      'shortNameTranslation': {'ar': 'د. بلايند'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 10.8, 'y': 47.5, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 26.2, 'z': 8.3},
#    'blockCoordinates': {'x': 2.9, 'y': 69.3, 'z': 0},
#    'xg': 0.036967672407627,
#    'id': 2464315,
#    'time': 22,
#    'timeSeconds': 1297,
#    'draw': {'start': {'x': 47.5, 'y': 10.8},
#     'block': {'x': 69.3, 'y': 2.9},
#     'end': {'x': 73.8, 'y': 0},
#     'goal': {'x': 73.8, 'y': 91.7}},
#    'reversedPeriodTime': 24,
#    'reversedPeriodTimeSeconds': 1403,
#    'incidentType': 'shot'},
#   {'player': {'name': 'André Silva',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'andre-silva',
#     'shortName': 'A. Silva',
#     'position': 'F',
#     'jerseyNumber': '21',
#     'userCount': 6823,
#     'id': 190159,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'},
#      'shortNameTranslation': {'ar': 'أ. سيلفا'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 19.7, 'y': 64.2, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 58.5, 'z': 91.7},
#    'xg': 0.042388796806335,
#    'id': 2464310,
#    'time': 19,
#    'timeSeconds': 1083,
#    'draw': {'start': {'x': 64.2, 'y': 19.7},
#     'end': {'x': 41.5, 'y': 0},
#     'goal': {'x': 41.5, 'y': 8.3}},
#    'reversedPeriodTime': 27,
#    'reversedPeriodTimeSeconds': 1617,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Viktor Tsygankov',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'viktor-tsygankov',
#     'shortName': 'V. Tsygankov',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 4366,
#     'id': 319735,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فيكتور تسيغانكوف'},
#      'shortNameTranslation': {'ar': 'ف. تسيغانكوف'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 23, 'y': 62.7, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 46.1, 'z': 20.9},
#    'blockCoordinates': {'x': 1.2, 'y': 48.7, 'z': 0},
#    'xg': 0.078218907117844,
#    'xgot': 0.3137,
#    'id': 2464294,
#    'time': 14,
#    'timeSeconds': 833,
#    'draw': {'start': {'x': 62.7, 'y': 23},
#     'block': {'x': 48.7, 'y': 1.2},
#     'end': {'x': 53.9, 'y': 0},
#     'goal': {'x': 53.9, 'y': 79.1}},
#    'reversedPeriodTime': 32,
#    'reversedPeriodTimeSeconds': 1867,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Brais Méndez',
#     'slug': 'brais-mendez',
#     'shortName': 'B. Méndez',
#     'position': 'M',
#     'jerseyNumber': '23',
#     'userCount': 2003,
#     'id': 845385,
#     'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'},
#      'shortNameTranslation': {'ar': 'ب. منديز'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 21.2, 'y': 66.3, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.5, 'z': 19},
#    'blockCoordinates': {'x': 18, 'y': 63.9, 'z': 0},
#    'xg': 0.027705032378435,
#    'id': 2464274,
#    'time': 11,
#    'timeSeconds': 621,
#    'draw': {'start': {'x': 66.3, 'y': 21.2},
#     'block': {'x': 63.9, 'y': 18},
#     'end': {'x': 50.5, 'y': 0},
#     'goal': {'x': 50.5, 'y': 81}},
#    'reversedPeriodTime': 35,
#    'reversedPeriodTimeSeconds': 2079,
#    'incidentType': 'shot'}]}

# %%
len(shots['shotmap'])
# Out:
# 22

# %%
for i in range(0, len(shots['shotmap'])):
    print(shots['shotmap'][i])
# Out:
# {'player': {'name': 'Yangel Herrera', 'slug': 'yangel-herrera', 'shortName': 'Y. Herrera', 'position': 'M', 'jerseyNumber': '21', 'userCount': 2365, 'id': 839585, 'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'}, 'shortNameTranslation': {'ar': 'ي. هيريرا'}}}, 'isHome': True, 'shotType': 'block', 'situation': 'corner', 'playerCoordinates': {'x': 9.4, 'y': 42.4, 'z': 0}, 'bodyPart': 'head', 'goalMouthLocation': 'low-left', 'goalMouthCoordinates': {'x': 0, 'y': 52.2, 'z': 19}, 'blockCoordinates': {'x': 7.5, 'y': 43.5, 'z': 0}, 'xg': 0.024029621854424, 'id': 2464622, 'time': 90, 'addedTime': 7, 'timeSeconds': 5760, 'draw': {'start': {'x': 42.4, 'y': 9.4}, 'block': {'x': 43.5, 'y': 7.5}, 'end': {'x': 47.8, 'y': 0}, 'goal': {'x': 47.8, 'y': 81}}, 'reversedPeriodTime': 1, 'reversedPeriodTimeSeconds': 540, 'incidentType': 'shot'}
# {'player': {'name': 'Yangel Herrera', 'slug': 'yangel-herrera', 'shortName': 'Y. Herrera', 'position': 'M', 'jerseyNumber': '21', 'userCount': 2365, 'id': 839585, 'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'}, 'shortNameTranslation': {'ar': 'ي. هيريرا'}}}, 'isHome': True, 'shotType': 'block', 'situation': 'assisted', 'playerCoordinates': {'x': 13.6, 'y': 59, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'low-left', 'goalMouthCoordinates': {'x': 0, 'y': 52.8, 'z': 19}, 'blockCoordinates': {'x': 10.7, 'y': 56.5, 'z': 0}, 'xg': 0.057783525437117, 'id': 2464621, 'time': 90, 'addedTime': 6, 'timeSeconds': 5738, 'draw': {'start': {'x': 59, 'y': 13.6}, 'block': {'x': 56.5, 'y': 10.7}, 'end': {'x': 47.2, 'y': 0}, 'goal': {'x': 47.2, 'y': 81}}, 'reversedPeriodTime': 1, 'reversedPeriodTimeSeconds': 562, 'incidentType': 'shot'}
# {'player': {'name': 'Valery Fernández', 'slug': 'valery-fernandez', 'shortName': 'V. Fernández', 'position': 'D', 'jerseyNumber': '11', 'userCount': 360, 'id': 962378, 'fieldTranslations': {'nameTranslation': {'ar': 'فرنانديز ، فاليري'}, 'shortNameTranslation': {'ar': 'ف. ، فاليري'}}}, 'isHome': True, 'shotType': 'miss', 'situation': 'assisted', 'playerCoordinates': {'x': 9.4, 'y': 47.9, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'right', 'goalMouthCoordinates': {'x': 0, 'y': 40.3, 'z': 18.1}, 'xg': 0.19038042426109, 'id': 2464620, 'time': 90, 'addedTime': 5, 'timeSeconds': 5661, 'draw': {'start': {'x': 47.9, 'y': 9.4}, 'end': {'x': 59.7, 'y': 0}, 'goal': {'x': 59.7, 'y': 81.9}}, 'reversedPeriodTime': 1, 'reversedPeriodTimeSeconds': 639, 'incidentType': 'shot'}
# {'player': {'name': 'Daley Blind', 'firstName': '', 'lastName': '', 'slug': 'daley-blind', 'shortName': 'D. Blind', 'position': 'D', 'jerseyNumber': '17', 'userCount': 3766, 'id': 44864, 'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'}, 'shortNameTranslation': {'ar': 'د. بلايند'}}}, 'isHome': True, 'shotType': 'block', 'situation': 'free-kick', 'playerCoordinates': {'x': 27.6, 'y': 61.1, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'low-right', 'goalMouthCoordinates': {'x': 0, 'y': 47.9, 'z': 19}, 'blockCoordinates': {'x': 19.5, 'y': 58.5, 'z': 0}, 'xg': 0.033932123333216, 'id': 2464617, 'time': 90, 'addedTime': 4, 'timeSeconds': 5621, 'draw': {'start': {'x': 61.1, 'y': 27.6}, 'block': {'x': 58.5, 'y': 19.5}, 'end': {'x': 52.1, 'y': 0}, 'goal': {'x': 52.1, 'y': 81}}, 'reversedPeriodTime': 1, 'reversedPeriodTimeSeconds': 679, 'incidentType': 'shot'}
# {'player': {'name': 'Jon Pacheco', 'firstName': '', 'lastName': '', 'slug': 'jon-pacheco', 'shortName': 'J. Pacheco', 'position': 'D', 'jerseyNumber': '20', 'userCount': 238, 'id': 934383, 'fieldTranslations': {'nameTranslation': {'ar': 'جون باتشيكو'}, 'shortNameTranslation': {'ar': 'ج. باتشيكو'}}}, 'isHome': False, 'shotType': 'block', 'situation': 'set-piece', 'playerCoordinates': {'x': 10.6, 'y': 44.9, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'low-left', 'goalMouthCoordinates': {'x': 0, 'y': 52.8, 'z': 19}, 'blockCoordinates': {'x': 7.1, 'y': 45.7, 'z': 0}, 'xg': 0.069741666316986, 'id': 2464608, 'time': 90, 'timeSeconds': 5353, 'draw': {'start': {'x': 44.9, 'y': 10.6}, 'block': {'x': 45.7, 'y': 7.1}, 'end': {'x': 47.2, 'y': 0}, 'goal': {'x': 47.2, 'y': 81}}, 'reversedPeriodTime': 1, 'reversedPeriodTimeSeconds': 47, 'incidentType': 'shot'}
# {'player': {'name': 'Yangel Herrera', 'slug': 'yangel-herrera', 'shortName': 'Y. Herrera', 'position': 'M', 'jerseyNumber': '21', 'userCount': 2365, 'id': 839585, 'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'}, 'shortNameTranslation': {'ar': 'ي. هيريرا'}}}, 'isHome': True, 'shotType': 'save', 'situation': 'assisted', 'playerCoordinates': {'x': 9.5, 'y': 66.4, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'low-right', 'goalMouthCoordinates': {'x': 0, 'y': 46.9, 'z': 3.2}, 'blockCoordinates': {'x': 1.8, 'y': 52, 'z': 0}, 'xg': 0.043857332319021, 'xgot': 0.1397, 'id': 2464590, 'time': 83, 'timeSeconds': 4934, 'draw': {'start': {'x': 66.4, 'y': 9.5}, 'block': {'x': 52, 'y': 1.8}, 'end': {'x': 53.1, 'y': 0}, 'goal': {'x': 53.1, 'y': 96.8}}, 'reversedPeriodTime': 8, 'reversedPeriodTimeSeconds': 466, 'incidentType': 'shot'}
# {'player': {'name': 'Igor Zubeldia', 'slug': 'igor-zubeldia', 'shortName': 'I. Zubeldia', 'position': 'D', 'jerseyNumber': '5', 'userCount': 658, 'id': 838159, 'fieldTranslations': {'nameTranslation': {'ar': 'زوبيلديا, إيجور'}, 'shortNameTranslation': {'ar': 'إ. زوبيلديا'}}}, 'isHome': False, 'shotType': 'miss', 'situation': 'corner', 'playerCoordinates': {'x': 7.1, 'y': 45.1, 'z': 0}, 'bodyPart': 'head', 'goalMouthLocation': 'right', 'goalMouthCoordinates': {'x': 0, 'y': 0.8, 'z': 11.1}, 'blockCoordinates': {'x': 12.1, 'y': 88.3, 'z': 0}, 'xg': 0.10778696089983, 'id': 2464584, 'time': 77, 'timeSeconds': 4585, 'draw': {'start': {'x': 45.1, 'y': 7.1}, 'block': {'x': 88.3, 'y': 12.1}, 'end': {'x': 99.2, 'y': 0}, 'goal': {'x': 99.2, 'y': 88.9}}, 'reversedPeriodTime': 14, 'reversedPeriodTimeSeconds': 815, 'incidentType': 'shot'}
# {'player': {'name': 'Brais Méndez', 'slug': 'brais-mendez', 'shortName': 'B. Méndez', 'position': 'M', 'jerseyNumber': '23', 'userCount': 1967, 'id': 845385, 'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'}, 'shortNameTranslation': {'ar': 'ب. منديز'}}}, 'isHome': False, 'shotType': 'save', 'situation': 'regular', 'playerCoordinates': {'x': 10.5, 'y': 59.1, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'high-centre', 'goalMouthCoordinates': {'x': 0, 'y': 50.3, 'z': 34.2}, 'blockCoordinates': {'x': 0.7, 'y': 51.1, 'z': 0}, 'xg': 0.1620799601078, 'xgot': 0.0776, 'id': 2464553, 'time': 72, 'timeSeconds': 4316, 'draw': {'start': {'x': 59.1, 'y': 10.5}, 'block': {'x': 51.1, 'y': 0.7}, 'end': {'x': 49.7, 'y': 0}, 'goal': {'x': 49.7, 'y': 65.8}}, 'reversedPeriodTime': 19, 'reversedPeriodTimeSeconds': 1084, 'incidentType': 'shot'}
# {'player': {'name': 'Jon Aramburu', 'firstName': 'Jon Aramburu', 'lastName': '', 'slug': 'jon-aramburu', 'shortName': 'J. Aramburu', 'position': 'M', 'jerseyNumber': '39', 'userCount': 343, 'id': 1116388}, 'isHome': False, 'shotType': 'miss', 'situation': 'assisted', 'playerCoordinates': {'x': 21.6, 'y': 76.9, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'high', 'goalMouthCoordinates': {'x': 0, 'y': 47.2, 'z': 77.8}, 'xg': 0.017356714233756, 'id': 2464547, 'time': 70, 'timeSeconds': 4143, 'draw': {'start': {'x': 76.9, 'y': 21.6}, 'end': {'x': 52.8, 'y': 0}, 'goal': {'x': 52.8, 'y': 22.2}}, 'reversedPeriodTime': 21, 'reversedPeriodTimeSeconds': 1257, 'incidentType': 'shot'}
# {'player': {'name': 'Aleix García', 'firstName': '', 'lastName': '', 'slug': 'aleix-garcia', 'shortName': 'A. García', 'position': 'M', 'jerseyNumber': '14', 'userCount': 2900, 'id': 796047, 'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'}, 'shortNameTranslation': {'ar': 'أ. جارسيا'}}}, 'isHome': True, 'shotType': 'block', 'situation': 'free-kick', 'playerCoordinates': {'x': 21.5, 'y': 41.3, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'low-centre', 'goalMouthCoordinates': {'x': 0, 'y': 49.6, 'z': 19}, 'blockCoordinates': {'x': 15, 'y': 44, 'z': 0}, 'xg': 0.096756622195244, 'id': 2464529, 'time': 65, 'timeSeconds': 3864, 'draw': {'start': {'x': 41.3, 'y': 21.5}, 'block': {'x': 44, 'y': 15}, 'end': {'x': 50.4, 'y': 0}, 'goal': {'x': 50.4, 'y': 81}}, 'reversedPeriodTime': 26, 'reversedPeriodTimeSeconds': 1536, 'incidentType': 'shot'}
# {'player': {'name': 'Mikel Oyarzabal', 'slug': 'mikel-oyarzabal', 'shortName': 'M. Oyarzabal', 'position': 'F', 'jerseyNumber': '10', 'userCount': 4500, 'id': 823622, 'fieldTranslations': {'nameTranslation': {'ar': 'أويارزابال, ميكيل'}, 'shortNameTranslation': {'ar': 'م. أويارزابال'}}}, 'isHome': False, 'shotType': 'block', 'situation': 'assisted', 'playerCoordinates': {'x': 21.2, 'y': 43.6, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'low-centre', 'goalMouthCoordinates': {'x': 0, 'y': 49.6, 'z': 19}, 'blockCoordinates': {'x': 18.1, 'y': 44.6, 'z': 0}, 'xg': 0.03315020725131, 'id': 2464512, 'time': 62, 'timeSeconds': 3668, 'draw': {'start': {'x': 43.6, 'y': 21.2}, 'block': {'x': 44.6, 'y': 18.1}, 'end': {'x': 50.4, 'y': 0}, 'goal': {'x': 50.4, 'y': 81}}, 'reversedPeriodTime': 29, 'reversedPeriodTimeSeconds': 1732, 'incidentType': 'shot'}
# {'player': {'name': 'Ander Barrenetxea', 'firstName': '', 'lastName': '', 'slug': 'ander-barrenetxea', 'shortName': 'A. Barrenetxea', 'position': 'F', 'jerseyNumber': '7', 'userCount': 1229, 'id': 966862, 'fieldTranslations': {'nameTranslation': {'ar': 'بارنيتكسيا, أندر'}, 'shortNameTranslation': {'ar': 'أ. بارنيتكسيا'}}}, 'isHome': False, 'shotType': 'block', 'situation': 'assisted', 'playerCoordinates': {'x': 20.4, 'y': 68.2, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'low-centre', 'goalMouthCoordinates': {'x': 0, 'y': 49.5, 'z': 19}, 'blockCoordinates': {'x': 17.7, 'y': 65.9, 'z': 0}, 'xg': 0.03002449683845, 'id': 2464493, 'time': 57, 'timeSeconds': 3411, 'draw': {'start': {'x': 68.2, 'y': 20.4}, 'block': {'x': 65.9, 'y': 17.7}, 'end': {'x': 50.5, 'y': 0}, 'goal': {'x': 50.5, 'y': 81}}, 'reversedPeriodTime': 34, 'reversedPeriodTimeSeconds': 1989, 'incidentType': 'shot'}
# {'player': {'name': 'Sheraldo Becker', 'slug': 'sheraldo-becker', 'shortName': 'S. Becker', 'position': 'F', 'jerseyNumber': '11', 'userCount': 1613, 'id': 352544, 'fieldTranslations': {'nameTranslation': {'ar': 'شيرالدو بيكر'}, 'shortNameTranslation': {'ar': 'ش. بيكر'}}}, 'isHome': False, 'shotType': 'miss', 'situation': 'assisted', 'playerCoordinates': {'x': 18.1, 'y': 70.7, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'close-right', 'goalMouthCoordinates': {'x': 0, 'y': 42.9, 'z': 2.8}, 'xg': 0.04538705945015, 'id': 2464477, 'time': 50, 'timeSeconds': 2998, 'draw': {'start': {'x': 70.7, 'y': 18.1}, 'end': {'x': 57.1, 'y': 0}, 'goal': {'x': 57.1, 'y': 97.2}}, 'reversedPeriodTime': 41, 'reversedPeriodTimeSeconds': 2402, 'incidentType': 'shot'}
# {'player': {'name': 'André Silva', 'firstName': '', 'lastName': '', 'slug': 'andre-silva', 'shortName': 'A. Silva', 'position': 'F', 'jerseyNumber': '21', 'userCount': 6798, 'id': 190159, 'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'}, 'shortNameTranslation': {'ar': 'أ. سيلفا'}}}, 'isHome': False, 'shotType': 'miss', 'situation': 'regular', 'playerCoordinates': {'x': 22.3, 'y': 46.7, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'close-left', 'goalMouthCoordinates': {'x': 0, 'y': 56.8, 'z': 5.6}, 'xg': 0.023845247924328, 'id': 2464472, 'time': 49, 'timeSeconds': 2918, 'draw': {'start': {'x': 46.7, 'y': 22.3}, 'end': {'x': 43.2, 'y': 0}, 'goal': {'x': 43.2, 'y': 94.4}}, 'reversedPeriodTime': 42, 'reversedPeriodTimeSeconds': 2482, 'incidentType': 'shot'}
# {'player': {'name': 'André Silva', 'firstName': '', 'lastName': '', 'slug': 'andre-silva', 'shortName': 'A. Silva', 'position': 'F', 'jerseyNumber': '21', 'userCount': 6798, 'id': 190159, 'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'}, 'shortNameTranslation': {'ar': 'أ. سيلفا'}}}, 'isHome': False, 'shotType': 'save', 'situation': 'assisted', 'playerCoordinates': {'x': 22.2, 'y': 54.3, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'low-left', 'goalMouthCoordinates': {'x': 0, 'y': 51.9, 'z': 1.3}, 'blockCoordinates': {'x': 0.5, 'y': 50.7, 'z': 0}, 'xg': 0.043737564235926, 'xgot': 0.1055, 'id': 2464338, 'time': 31, 'timeSeconds': 1813, 'draw': {'start': {'x': 54.3, 'y': 22.2}, 'block': {'x': 50.7, 'y': 0.5}, 'end': {'x': 48.1, 'y': 0}, 'goal': {'x': 48.1, 'y': 98.7}}, 'reversedPeriodTime': 15, 'reversedPeriodTimeSeconds': 887, 'incidentType': 'shot'}
# {'player': {'name': 'Sávio', 'firstName': 'Sávio', 'lastName': '', 'slug': 'savio', 'shortName': 'Sávio', 'position': 'M', 'jerseyNumber': '16', 'userCount': 5695, 'id': 1046795, 'fieldTranslations': {'nameTranslation': {'ar': 'سافيو'}, 'shortNameTranslation': {'ar': 'سافيو'}}}, 'isHome': True, 'shotType': 'miss', 'situation': 'assisted', 'playerCoordinates': {'x': 15, 'y': 30.4, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'right', 'goalMouthCoordinates': {'x': 0, 'y': 34.6, 'z': 26.4}, 'xg': 0.034219179302454, 'id': 2464337, 'time': 29, 'timeSeconds': 1734, 'draw': {'start': {'x': 30.4, 'y': 15}, 'end': {'x': 65.4, 'y': 0}, 'goal': {'x': 65.4, 'y': 73.6}}, 'reversedPeriodTime': 17, 'reversedPeriodTimeSeconds': 966, 'incidentType': 'shot'}
# {'player': {'name': 'Miguel Gutiérrez', 'slug': 'miguel-gutierrez', 'shortName': 'M. Gutiérrez', 'position': 'D', 'jerseyNumber': '3', 'userCount': 2755, 'id': 908716, 'fieldTranslations': {'nameTranslation': {'ar': 'جوتيريز ، ميغيل'}, 'shortNameTranslation': {'ar': 'ج. ، ميغيل'}}}, 'isHome': True, 'shotType': 'block', 'situation': 'corner', 'playerCoordinates': {'x': 18.8, 'y': 51.9, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'low-centre', 'goalMouthCoordinates': {'x': 0, 'y': 51.7, 'z': 19}, 'blockCoordinates': {'x': 11.8, 'y': 50.5, 'z': 0}, 'xg': 0.055620305240154, 'id': 2464319, 'time': 23, 'timeSeconds': 1331, 'draw': {'start': {'x': 51.9, 'y': 18.8}, 'block': {'x': 50.5, 'y': 11.8}, 'end': {'x': 48.3, 'y': 0}, 'goal': {'x': 48.3, 'y': 81}}, 'reversedPeriodTime': 23, 'reversedPeriodTimeSeconds': 1369, 'incidentType': 'shot'}
# {'player': {'name': 'Aleix García', 'firstName': '', 'lastName': '', 'slug': 'aleix-garcia', 'shortName': 'A. García', 'position': 'M', 'jerseyNumber': '14', 'userCount': 2900, 'id': 796047, 'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'}, 'shortNameTranslation': {'ar': 'أ. جارسيا'}}}, 'isHome': True, 'shotType': 'save', 'situation': 'corner', 'playerCoordinates': {'x': 13.8, 'y': 59.9, 'z': 0}, 'bodyPart': 'right-foot', 'goalMouthLocation': 'low-centre', 'goalMouthCoordinates': {'x': 0, 'y': 48.7, 'z': 8.9}, 'blockCoordinates': {'x': 1.2, 'y': 50.7, 'z': 0}, 'xg': 0.068754702806473, 'xgot': 0.0398, 'id': 2464318, 'time': 23, 'timeSeconds': 1329, 'draw': {'start': {'x': 59.9, 'y': 13.8}, 'block': {'x': 50.7, 'y': 1.2}, 'end': {'x': 51.3, 'y': 0}, 'goal': {'x': 51.3, 'y': 91.1}}, 'reversedPeriodTime': 23, 'reversedPeriodTimeSeconds': 1371, 'incidentType': 'shot'}
# {'player': {'name': 'Daley Blind', 'firstName': '', 'lastName': '', 'slug': 'daley-blind', 'shortName': 'D. Blind', 'position': 'D', 'jerseyNumber': '17', 'userCount': 3766, 'id': 44864, 'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'}, 'shortNameTranslation': {'ar': 'د. بلايند'}}}, 'isHome': True, 'shotType': 'miss', 'situation': 'set-piece', 'playerCoordinates': {'x': 10.8, 'y': 47.5, 'z': 0}, 'bodyPart': 'head', 'goalMouthLocation': 'right', 'goalMouthCoordinates': {'x': 0, 'y': 26.2, 'z': 8.3}, 'blockCoordinates': {'x': 2.9, 'y': 69.3, 'z': 0}, 'xg': 0.036967672407627, 'id': 2464315, 'time': 22, 'timeSeconds': 1297, 'draw': {'start': {'x': 47.5, 'y': 10.8}, 'block': {'x': 69.3, 'y': 2.9}, 'end': {'x': 73.8, 'y': 0}, 'goal': {'x': 73.8, 'y': 91.7}}, 'reversedPeriodTime': 24, 'reversedPeriodTimeSeconds': 1403, 'incidentType': 'shot'}
# {'player': {'name': 'André Silva', 'firstName': '', 'lastName': '', 'slug': 'andre-silva', 'shortName': 'A. Silva', 'position': 'F', 'jerseyNumber': '21', 'userCount': 6798, 'id': 190159, 'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'}, 'shortNameTranslation': {'ar': 'أ. سيلفا'}}}, 'isHome': False, 'shotType': 'miss', 'situation': 'assisted', 'playerCoordinates': {'x': 19.7, 'y': 64.2, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'high-left', 'goalMouthCoordinates': {'x': 0, 'y': 58.5, 'z': 91.7}, 'xg': 0.042388796806335, 'id': 2464310, 'time': 19, 'timeSeconds': 1083, 'draw': {'start': {'x': 64.2, 'y': 19.7}, 'end': {'x': 41.5, 'y': 0}, 'goal': {'x': 41.5, 'y': 8.3}}, 'reversedPeriodTime': 27, 'reversedPeriodTimeSeconds': 1617, 'incidentType': 'shot'}
# {'player': {'name': 'Viktor Tsygankov', 'firstName': '', 'lastName': '', 'slug': 'viktor-tsygankov', 'shortName': 'V. Tsygankov', 'position': 'M', 'jerseyNumber': '8', 'userCount': 4344, 'id': 319735, 'fieldTranslations': {'nameTranslation': {'ar': 'فيكتور تسيغانكوف'}, 'shortNameTranslation': {'ar': 'ف. تسيغانكوف'}}}, 'isHome': True, 'shotType': 'save', 'situation': 'free-kick', 'playerCoordinates': {'x': 23, 'y': 62.7, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'high-right', 'goalMouthCoordinates': {'x': 0, 'y': 46.1, 'z': 20.9}, 'blockCoordinates': {'x': 1.2, 'y': 48.7, 'z': 0}, 'xg': 0.078218907117844, 'xgot': 0.3137, 'id': 2464294, 'time': 14, 'timeSeconds': 833, 'draw': {'start': {'x': 62.7, 'y': 23}, 'block': {'x': 48.7, 'y': 1.2}, 'end': {'x': 53.9, 'y': 0}, 'goal': {'x': 53.9, 'y': 79.1}}, 'reversedPeriodTime': 32, 'reversedPeriodTimeSeconds': 1867, 'incidentType': 'shot'}
# {'player': {'name': 'Brais Méndez', 'slug': 'brais-mendez', 'shortName': 'B. Méndez', 'position': 'M', 'jerseyNumber': '23', 'userCount': 1967, 'id': 845385, 'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'}, 'shortNameTranslation': {'ar': 'ب. منديز'}}}, 'isHome': False, 'shotType': 'block', 'situation': 'assisted', 'playerCoordinates': {'x': 21.2, 'y': 66.3, 'z': 0}, 'bodyPart': 'left-foot', 'goalMouthLocation': 'low-centre', 'goalMouthCoordinates': {'x': 0, 'y': 49.5, 'z': 19}, 'blockCoordinates': {'x': 18, 'y': 63.9, 'z': 0}, 'xg': 0.027705032378435, 'id': 2464274, 'time': 11, 'timeSeconds': 621, 'draw': {'start': {'x': 66.3, 'y': 21.2}, 'block': {'x': 63.9, 'y': 18}, 'end': {'x': 50.5, 'y': 0}, 'goal': {'x': 50.5, 'y': 81}}, 'reversedPeriodTime': 35, 'reversedPeriodTimeSeconds': 2079, 'incidentType': 'shot'}

# %%
#convert to pandas dataframe
import pandas as pd
df = pd.DataFrame(shots['shotmap'])
df.head()
# Out:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_15632\4002465955.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                               player  isHome shotType  \
# 0  {'name': 'Yangel Herrera', 'slug': 'yangel-her...    True    block
# 1  {'name': 'Yangel Herrera', 'slug': 'yangel-her...    True    block
# 2  {'name': 'Valery Fernández', 'slug': 'valery-f...    True     miss
# 3  {'name': 'Daley Blind', 'firstName': '', 'last...    True    block
# 4  {'name': 'Jon Pacheco', 'firstName': '', 'last...   False    block
#
#    situation               playerCoordinates   bodyPart goalMouthLocation  \
# 0     corner   {'x': 9.4, 'y': 42.4, 'z': 0}       head          low-left
# 1   assisted    {'x': 13.6, 'y': 59, 'z': 0}  left-foot          low-left
# 2   assisted   {'x': 9.4, 'y': 47.9, 'z': 0}  left-foot             right
# 3  free-kick  {'x': 27.6, 'y': 61.1, 'z': 0}  left-foot         low-right
# 4  set-piece  {'x': 10.6, 'y': 44.9, 'z': 0}  left-foot          low-left
#
#              goalMouthCoordinates                blockCoordinates        xg  \
# 0    {'x': 0, 'y': 52.2, 'z': 19}   {'x': 7.5, 'y': 43.5, 'z': 0}  0.024030
# 1    {'x': 0, 'y': 52.8, 'z': 19}  {'x': 10.7, 'y': 56.5, 'z': 0}  0.057784
# 2  {'x': 0, 'y': 40.3, 'z': 18.1}                             NaN  0.190380
# 3    {'x': 0, 'y': 47.9, 'z': 19}  {'x': 19.5, 'y': 58.5, 'z': 0}  0.033932
# 4    {'x': 0, 'y': 52.8, 'z': 19}   {'x': 7.1, 'y': 45.7, 'z': 0}  0.069742
#
#         id  time  addedTime  timeSeconds  \
# 0  2464622    90        7.0         5760
# 1  2464621    90        6.0         5738
# 2  2464620    90        5.0         5661
# 3  2464617    90        4.0         5621
# 4  2464608    90        NaN         5353
#
#                                                 draw  reversedPeriodTime  \
# 0  {'start': {'x': 42.4, 'y': 9.4}, 'block': {'x'...                   1
# 1  {'start': {'x': 59, 'y': 13.6}, 'block': {'x':...                   1
# 2  {'start': {'x': 47.9, 'y': 9.4}, 'end': {'x': ...                   1
# 3  {'start': {'x': 61.1, 'y': 27.6}, 'block': {'x...                   1
# 4  {'start': {'x': 44.9, 'y': 10.6}, 'block': {'x...                   1
#
#    reversedPeriodTimeSeconds incidentType  xgot
# 0                        540         shot   NaN
# 1                        562         shot   NaN
# 2                        639         shot   NaN
# 3                        679         shot   NaN
# 4                         47         shot   NaN

# %%
df[['name', 'position', 'jerseyNumber']] = df['player'].apply(lambda x: pd.Series({'name': x['name'], 'position': x['position'], 'jerseyNumber': x['jerseyNumber']}))
df.drop('player', axis=1, inplace=True)

# %%
df.head()
# Out:
#    isHome shotType  situation               playerCoordinates   bodyPart  \
# 0    True    block     corner   {'x': 9.4, 'y': 42.4, 'z': 0}       head
# 1    True    block   assisted    {'x': 13.6, 'y': 59, 'z': 0}  left-foot
# 2    True     miss   assisted   {'x': 9.4, 'y': 47.9, 'z': 0}  left-foot
# 3    True    block  free-kick  {'x': 27.6, 'y': 61.1, 'z': 0}  left-foot
# 4   False    block  set-piece  {'x': 10.6, 'y': 44.9, 'z': 0}  left-foot
#
#   goalMouthLocation            goalMouthCoordinates  \
# 0          low-left    {'x': 0, 'y': 52.2, 'z': 19}
# 1          low-left    {'x': 0, 'y': 52.8, 'z': 19}
# 2             right  {'x': 0, 'y': 40.3, 'z': 18.1}
# 3         low-right    {'x': 0, 'y': 47.9, 'z': 19}
# 4          low-left    {'x': 0, 'y': 52.8, 'z': 19}
#
#                  blockCoordinates        xg       id  ...  addedTime  \
# 0   {'x': 7.5, 'y': 43.5, 'z': 0}  0.024030  2464622  ...        7.0
# 1  {'x': 10.7, 'y': 56.5, 'z': 0}  0.057784  2464621  ...        6.0
# 2                             NaN  0.190380  2464620  ...        5.0
# 3  {'x': 19.5, 'y': 58.5, 'z': 0}  0.033932  2464617  ...        4.0
# 4   {'x': 7.1, 'y': 45.7, 'z': 0}  0.069742  2464608  ...        NaN
#
#    timeSeconds                                               draw  \
# 0         5760  {'start': {'x': 42.4, 'y': 9.4}, 'block': {'x'...
# 1         5738  {'start': {'x': 59, 'y': 13.6}, 'block': {'x':...
# 2         5661  {'start': {'x': 47.9, 'y': 9.4}, 'end': {'x': ...
# 3         5621  {'start': {'x': 61.1, 'y': 27.6}, 'block': {'x...
# 4         5353  {'start': {'x': 44.9, 'y': 10.6}, 'block': {'x...
#
#   reversedPeriodTime  reversedPeriodTimeSeconds  incidentType xgot  \
# 0                  1                        540          shot  NaN
# 1                  1                        562          shot  NaN
# 2                  1                        639          shot  NaN
# 3                  1                        679          shot  NaN
# 4                  1                         47          shot  NaN
#
#                name position jerseyNumber
# 0    Yangel Herrera        M           21
# 1    Yangel Herrera        M           21
# 2  Valery Fernández        D           11
# 3       Daley Blind        D           23
# 4       Jon Pacheco        D           20
#
# [5 rows x 21 columns]

# %%
#can you mve player name, position and jersey number to the start of the dataframe
cols = df.columns.tolist()
cols = cols[-3:] + cols[:-3]
df = df[cols]

# %%
df.head()
# Out:
#                name position jerseyNumber  isHome shotType  situation  \
# 0    Yangel Herrera        M           21    True    block     corner
# 1    Yangel Herrera        M           21    True    block   assisted
# 2  Valery Fernández        D           11    True     miss   assisted
# 3       Daley Blind        D           23    True    block  free-kick
# 4       Jon Pacheco        D           20   False    block  set-piece
#
#                 playerCoordinates   bodyPart goalMouthLocation  \
# 0   {'x': 9.4, 'y': 42.4, 'z': 0}       head          low-left
# 1    {'x': 13.6, 'y': 59, 'z': 0}  left-foot          low-left
# 2   {'x': 9.4, 'y': 47.9, 'z': 0}  left-foot             right
# 3  {'x': 27.6, 'y': 61.1, 'z': 0}  left-foot         low-right
# 4  {'x': 10.6, 'y': 44.9, 'z': 0}  left-foot          low-left
#
#              goalMouthCoordinates  ...        xg       id  time  addedTime  \
# 0    {'x': 0, 'y': 52.2, 'z': 19}  ...  0.024030  2464622    90        7.0
# 1    {'x': 0, 'y': 52.8, 'z': 19}  ...  0.057784  2464621    90        6.0
# 2  {'x': 0, 'y': 40.3, 'z': 18.1}  ...  0.190380  2464620    90        5.0
# 3    {'x': 0, 'y': 47.9, 'z': 19}  ...  0.033932  2464617    90        4.0
# 4    {'x': 0, 'y': 52.8, 'z': 19}  ...  0.069742  2464608    90        NaN
#
#    timeSeconds                                               draw  \
# 0         5760  {'start': {'x': 42.4, 'y': 9.4}, 'block': {'x'...
# 1         5738  {'start': {'x': 59, 'y': 13.6}, 'block': {'x':...
# 2         5661  {'start': {'x': 47.9, 'y': 9.4}, 'end': {'x': ...
# 3         5621  {'start': {'x': 61.1, 'y': 27.6}, 'block': {'x...
# 4         5353  {'start': {'x': 44.9, 'y': 10.6}, 'block': {'x...
#
#   reversedPeriodTime  reversedPeriodTimeSeconds  incidentType xgot
# 0                  1                        540          shot  NaN
# 1                  1                        562          shot  NaN
# 2                  1                        639          shot  NaN
# 3                  1                        679          shot  NaN
# 4                  1                         47          shot  NaN
#
# [5 rows x 21 columns]

# %%
df[['xCoord', 'yCoord']] = df['playerCoordinates'].apply(lambda x: pd.Series({'x': x['x'], 'y': x['y']}))
df.drop('playerCoordinates', axis=1, inplace=True)

# %%
df[['GoalMouthxCoord', 'GoalMouthyCoord', 'GoalMouthzCoord']] = df['goalMouthCoordinates'].apply(lambda x: pd.Series({'x': x['x'], 'y': x['y'], 'z': x['z']}))
df.drop('goalMouthCoordinates', axis=1, inplace=True)

# %%
df['blockCoordinates']
# Out:
# 0      {'x': 7.5, 'y': 43.5, 'z': 0}
# 1     {'x': 10.7, 'y': 56.5, 'z': 0}
# 2                                NaN
# 3     {'x': 19.5, 'y': 58.5, 'z': 0}
# 4      {'x': 7.1, 'y': 45.7, 'z': 0}
# 5        {'x': 1.8, 'y': 52, 'z': 0}
# 6     {'x': 12.1, 'y': 88.3, 'z': 0}
# 7      {'x': 0.7, 'y': 51.1, 'z': 0}
# 8                                NaN
# 9         {'x': 15, 'y': 44, 'z': 0}
# 10    {'x': 18.1, 'y': 44.6, 'z': 0}
# 11    {'x': 17.7, 'y': 65.9, 'z': 0}
# 12                               NaN
# 13                               NaN
# 14     {'x': 0.5, 'y': 50.7, 'z': 0}
# 15                               NaN
# 16    {'x': 11.8, 'y': 50.5, 'z': 0}
# 17     {'x': 1.2, 'y': 50.7, 'z': 0}
# 18     {'x': 2.9, 'y': 69.3, 'z': 0}
# 19                               NaN
# 20     {'x': 1.2, 'y': 48.7, 'z': 0}
# 21      {'x': 18, 'y': 63.9, 'z': 0}
# Name: blockCoordinates, dtype: object

# %%
df[['BlockxCoord', 'BlockyCoord']] = df['blockCoordinates'].apply(lambda x: pd.Series({'x': x['x'], 'y': x['y']}) if isinstance(x, dict) else pd.Series({'x': pd.NA, 'y': pd.NA}))
df.drop('blockCoordinates', axis=1, inplace=True)

# %%
df.head()
# Out:
#                name position jerseyNumber  isHome shotType  situation  \
# 0    Yangel Herrera        M           21    True    block     corner
# 1    Yangel Herrera        M           21    True    block   assisted
# 2  Valery Fernández        D           11    True     miss   assisted
# 3       Daley Blind        D           23    True    block  free-kick
# 4       Jon Pacheco        D           20   False    block  set-piece
#
#     bodyPart goalMouthLocation        xg       id  ...  \
# 0       head          low-left  0.024030  2464622  ...
# 1  left-foot          low-left  0.057784  2464621  ...
# 2  left-foot             right  0.190380  2464620  ...
# 3  left-foot         low-right  0.033932  2464617  ...
# 4  left-foot          low-left  0.069742  2464608  ...
#
#    reversedPeriodTimeSeconds  incidentType  xgot xCoord  yCoord  \
# 0                        540          shot   NaN    9.4    42.4
# 1                        562          shot   NaN   13.6    59.0
# 2                        639          shot   NaN    9.4    47.9
# 3                        679          shot   NaN   27.6    61.1
# 4                         47          shot   NaN   10.6    44.9
#
#    GoalMouthxCoord GoalMouthyCoord  GoalMouthzCoord  BlockxCoord  BlockyCoord
# 0              0.0            52.2             19.0          7.5         43.5
# 1              0.0            52.8             19.0         10.7         56.5
# 2              0.0            40.3             18.1         <NA>         <NA>
# 3              0.0            47.9             19.0         19.5         58.5
# 4              0.0            52.8             19.0          7.1         45.7
#
# [5 rows x 25 columns]

# %%
#axis 1 means column poori drop hoaye gi, and 0 means row, but we want to drop the column
#inplace means usi df mein modify hojaye ga
df.drop('id', axis=1, inplace=True)

# %%
#conver timeseconds to minutes, and give ceiling value like if 10.6 give it 11 minutes
import math
df['Minute'] = df['timeSeconds'].apply(lambda x: math.ceil(x/60))

# %%
df.head()
# Out:
#                name position jerseyNumber  isHome shotType  situation  \
# 0    Yangel Herrera        M           21    True    block     corner
# 1    Yangel Herrera        M           21    True    block   assisted
# 2  Valery Fernández        D           11    True     miss   assisted
# 3       Daley Blind        D           23    True    block  free-kick
# 4       Jon Pacheco        D           20   False    block  set-piece
#
#     bodyPart goalMouthLocation        xg  time  ...  incidentType  xgot  \
# 0       head          low-left  0.024030    90  ...          shot   NaN
# 1  left-foot          low-left  0.057784    90  ...          shot   NaN
# 2  left-foot             right  0.190380    90  ...          shot   NaN
# 3  left-foot         low-right  0.033932    90  ...          shot   NaN
# 4  left-foot          low-left  0.069742    90  ...          shot   NaN
#
#   xCoord  yCoord  GoalMouthxCoord GoalMouthyCoord  GoalMouthzCoord  \
# 0    9.4    42.4              0.0            52.2             19.0
# 1   13.6    59.0              0.0            52.8             19.0
# 2    9.4    47.9              0.0            40.3             18.1
# 3   27.6    61.1              0.0            47.9             19.0
# 4   10.6    44.9              0.0            52.8             19.0
#
#    BlockxCoord  BlockyCoord  Minute
# 0          7.5         43.5      96
# 1         10.7         56.5      96
# 2         <NA>         <NA>      95
# 3         19.5         58.5      94
# 4          7.1         45.7      90
#
# [5 rows x 25 columns]

# %%
df.drop('timeSeconds', axis=1, inplace=True)
df.drop('time', axis=1, inplace=True)
df.drop('addedTime', axis=1, inplace=True)
df.drop('reversedPeriodTime', axis=1, inplace=True)
df.drop('reversedPeriodTimeSeconds', axis=1, inplace=True)

# %%
df[['EndLocation']] = df['draw'].apply(lambda x: pd.Series({'end': x['end']}))
df.drop('draw', axis=1, inplace=True)

# %%
df[['EndLocxCoord', 'EndLocyCoord']] = df['EndLocation'].apply(lambda x: pd.Series({'x': x['x'], 'y': x['y']}))
df.drop('EndLocation', axis=1, inplace=True)

# %%
df.head()
# Out:
#                name position jerseyNumber  isHome shotType  situation  \
# 0    Yangel Herrera        M           21    True    block     corner
# 1    Yangel Herrera        M           21    True    block   assisted
# 2  Valery Fernández        D           11    True     miss   assisted
# 3       Daley Blind        D           23    True    block  free-kick
# 4       Jon Pacheco        D           20   False    block  set-piece
#
#     bodyPart goalMouthLocation        xg incidentType  ...  xCoord  yCoord  \
# 0       head          low-left  0.024030         shot  ...     9.4    42.4
# 1  left-foot          low-left  0.057784         shot  ...    13.6    59.0
# 2  left-foot             right  0.190380         shot  ...     9.4    47.9
# 3  left-foot         low-right  0.033932         shot  ...    27.6    61.1
# 4  left-foot          low-left  0.069742         shot  ...    10.6    44.9
#
#    GoalMouthxCoord  GoalMouthyCoord  GoalMouthzCoord  BlockxCoord BlockyCoord  \
# 0              0.0             52.2             19.0          7.5        43.5
# 1              0.0             52.8             19.0         10.7        56.5
# 2              0.0             40.3             18.1         <NA>        <NA>
# 3              0.0             47.9             19.0         19.5        58.5
# 4              0.0             52.8             19.0          7.1        45.7
#
#   Minute  EndLocxCoord  EndLocyCoord
# 0     96          47.8           0.0
# 1     96          47.2           0.0
# 2     95          59.7           0.0
# 3     94          52.1           0.0
# 4     90          47.2           0.0
#
# [5 rows x 21 columns]

# %%
#convert to df to csv
df.to_csv('shots.csv', index=False)
