# %%
print('j')
# Out:
# j

# %%
import requests 
from bs4 import BeautifulSoup

# %%
import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'if-none-match': 'W/"ae3bef61a0"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
}
#get current date
import datetime
headers['If-Modified-Since']= datetime.datetime.now().isoformat()

response = requests.get('https://api.sofascore.com/api/v1/event/11369489/lineups', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
pstats=response.json()

# %%
pstats
# Out:
# {'confirmed': True,
#  'home': {'players': [{'player': {'name': 'Paulo Gazzaniga',
#      'slug': 'paulo-gazzaniga',
#      'shortName': 'P. Gazzaniga',
#      'position': 'G',
#      'jerseyNumber': '13',
#      'userCount': 1680,
#      'id': 164343,
#      'country': {'alpha2': 'AR', 'name': 'Argentina'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 694310400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'غازانيجا, باولو'},
#       'shortNameTranslation': {'ar': 'ب. غازانيجا'}}},
#     'shirtNumber': 13,
#     'jerseyNumber': '13',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'totalPass': 45,
#      'accuratePass': 26,
#      'totalLongBalls': 27,
#      'accurateLongBalls': 9,
#      'savedShotsFromInsideTheBox': 1,
#      'saves': 2,
#      'minutesPlayed': 90,
#      'touches': 51,
#      'rating': 7,
#      'possessionLostCtrl': 21,
#      'ratingVersions': {'original': 7, 'alternative': 7.3},
#      'goalsPrevented': 0.1831}},
#    {'player': {'name': 'Yan Couto',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'couto-yan',
#      'shortName': 'Y. Couto',
#      'position': 'M',
#      'jerseyNumber': '20',
#      'userCount': 3412,
#      'id': 1002813,
#      'country': {'alpha2': 'BR', 'name': 'Brazil'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1023062400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'يان كوتو'},
#       'shortNameTranslation': {'ar': 'ي. كوتو'}}},
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 52,
#      'accuratePass': 44,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 3,
#      'totalCross': 1,
#      'accurateCross': 1,
#      'aerialLost': 1,
#      'duelLost': 11,
#      'duelWon': 6,
#      'dispossessed': 4,
#      'totalContest': 8,
#      'wonContest': 3,
#      'bigChanceCreated': 1,
#      'totalTackle': 1,
#      'wasFouled': 2,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 83,
#      'rating': 6.8,
#      'possessionLostCtrl': 20,
#      'keyPass': 2,
#      'ratingVersions': {'original': 6.8, 'alternative': 6.7},
#      'expectedAssists': 0.195063}},
#    {'player': {'name': 'Eric García',
#      'slug': 'eric-garcia',
#      'shortName': 'E. García',
#      'position': 'D',
#      'jerseyNumber': '25',
#      'userCount': 8185,
#      'id': 876214,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 978998400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, اريك'},
#       'shortNameTranslation': {'ar': 'ا. جارسيا'}}},
#     'shirtNumber': 25,
#     'jerseyNumber': '25',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 52,
#      'accuratePass': 47,
#      'totalLongBalls': 4,
#      'accurateLongBalls': 3,
#      'aerialLost': 1,
#      'aerialWon': 2,
#      'duelLost': 2,
#      'duelWon': 6,
#      'totalClearance': 5,
#      'interceptionWon': 1,
#      'totalTackle': 3,
#      'wasFouled': 1,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 63,
#      'rating': 7.5,
#      'possessionLostCtrl': 5,
#      'ratingVersions': {'original': 7.5, 'alternative': 7.6},
#      'expectedAssists': 0.137272}},
#    {'player': {'name': 'Daley Blind',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'daley-blind',
#      'shortName': 'D. Blind',
#      'position': 'D',
#      'jerseyNumber': '17',
#      'userCount': 3766,
#      'id': 44864,
#      'country': {'alpha2': 'NL', 'name': 'Netherlands'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 636940800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'},
#       'shortNameTranslation': {'ar': 'د. بلايند'}}},
#     'shirtNumber': 17,
#     'jerseyNumber': '17',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 60,
#      'accuratePass': 54,
#      'totalLongBalls': 2,
#      'totalCross': 1,
#      'aerialLost': 2,
#      'aerialWon': 4,
#      'duelLost': 3,
#      'duelWon': 4,
#      'challengeLost': 1,
#      'shotOffTarget': 1,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 4,
#      'minutesPlayed': 90,
#      'touches': 73,
#      'rating': 6.9,
#      'possessionLostCtrl': 9,
#      'expectedGoals': 0.0709,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.9},
#      'expectedAssists': 0.00781402}},
#    {'player': {'name': 'Miguel Gutiérrez',
#      'slug': 'miguel-gutierrez',
#      'shortName': 'M. Gutiérrez',
#      'position': 'D',
#      'jerseyNumber': '3',
#      'userCount': 2755,
#      'id': 908716,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 996192000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جوتيريز ، ميغيل'},
#       'shortNameTranslation': {'ar': 'ج. ، ميغيل'}}},
#     'shirtNumber': 3,
#     'jerseyNumber': '3',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 35,
#      'accuratePass': 32,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 2,
#      'duelWon': 2,
#      'dispossessed': 1,
#      'totalContest': 1,
#      'wonContest': 1,
#      'blockedScoringAttempt': 1,
#      'outfielderBlock': 2,
#      'minutesPlayed': 90,
#      'touches': 51,
#      'rating': 7.2,
#      'possessionLostCtrl': 6,
#      'expectedGoals': 0.0556,
#      'keyPass': 1,
#      'ratingVersions': {'original': 7.2, 'alternative': 7.1},
#      'expectedAssists': 0.0363362}},
#    {'player': {'name': 'Yangel Herrera',
#      'slug': 'yangel-herrera',
#      'shortName': 'Y. Herrera',
#      'position': 'M',
#      'jerseyNumber': '21',
#      'userCount': 2365,
#      'id': 839585,
#      'country': {'alpha2': 'VE', 'name': 'Venezuela'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 884131200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'},
#       'shortNameTranslation': {'ar': 'ي. هيريرا'}}},
#     'shirtNumber': 21,
#     'jerseyNumber': '21',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 26,
#      'accuratePass': 22,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialLost': 4,
#      'aerialWon': 4,
#      'duelLost': 11,
#      'duelWon': 15,
#      'challengeLost': 3,
#      'dispossessed': 2,
#      'totalContest': 1,
#      'wonContest': 1,
#      'onTargetScoringAttempt': 1,
#      'blockedScoringAttempt': 2,
#      'totalClearance': 1,
#      'interceptionWon': 1,
#      'totalTackle': 4,
#      'wasFouled': 6,
#      'fouls': 2,
#      'minutesPlayed': 90,
#      'touches': 53,
#      'rating': 7.4,
#      'possessionLostCtrl': 9,
#      'expectedGoals': 0.1257,
#      'ratingVersions': {'original': 7.4, 'alternative': 7.1},
#      'expectedAssists': 0.00849824}},
#    {'player': {'name': 'Aleix García',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'aleix-garcia',
#      'shortName': 'A. García',
#      'position': 'M',
#      'jerseyNumber': '14',
#      'userCount': 2900,
#      'id': 796047,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 867456000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'},
#       'shortNameTranslation': {'ar': 'أ. جارسيا'}}},
#     'shirtNumber': 14,
#     'jerseyNumber': '14',
#     'position': 'M',
#     'substitute': False,
#     'captain': True,
#     'statistics': {'totalPass': 31,
#      'accuratePass': 28,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'duelLost': 1,
#      'duelWon': 5,
#      'onTargetScoringAttempt': 1,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 1,
#      'totalTackle': 3,
#      'errorLeadToAShot': 1,
#      'wasFouled': 2,
#      'fouls': 1,
#      'minutesPlayed': 80,
#      'touches': 44,
#      'rating': 7,
#      'possessionLostCtrl': 5,
#      'expectedGoals': 0.1655,
#      'keyPass': 1,
#      'ratingVersions': {'original': 7, 'alternative': 7},
#      'expectedAssists': 0.0613259}},
#    {'player': {'name': 'Viktor Tsygankov',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'viktor-tsygankov',
#      'shortName': 'V. Tsygankov',
#      'position': 'M',
#      'jerseyNumber': '8',
#      'userCount': 4344,
#      'id': 319735,
#      'country': {'alpha2': 'UA', 'name': 'Ukraine'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 879552000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فيكتور تسيغانكوف'},
#       'shortNameTranslation': {'ar': 'ف. تسيغانكوف'}}},
#     'shirtNumber': 8,
#     'jerseyNumber': '8',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 23,
#      'accuratePass': 16,
#      'totalLongBalls': 1,
#      'totalCross': 2,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 6,
#      'duelWon': 4,
#      'challengeLost': 1,
#      'dispossessed': 3,
#      'onTargetScoringAttempt': 1,
#      'totalClearance': 5,
#      'totalTackle': 3,
#      'fouls': 1,
#      'minutesPlayed': 80,
#      'touches': 40,
#      'rating': 6.9,
#      'possessionLostCtrl': 12,
#      'expectedGoals': 0.0782,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.6},
#      'expectedAssists': 0.0195499}},
#    {'player': {'name': 'Iván Martín',
#      'slug': 'ivan-martin',
#      'shortName': 'I. Martín',
#      'position': 'M',
#      'jerseyNumber': '23',
#      'userCount': 781,
#      'id': 973699,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 918950400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'مارتن, إيفان'},
#       'shortNameTranslation': {'ar': 'إ. مارتن'}}},
#     'shirtNumber': 23,
#     'jerseyNumber': '23',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 27,
#      'accuratePass': 23,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'duelWon': 4,
#      'totalTackle': 1,
#      'wasFouled': 3,
#      'minutesPlayed': 70,
#      'touches': 32,
#      'rating': 6.8,
#      'possessionLostCtrl': 4,
#      'ratingVersions': {'original': 6.8, 'alternative': 6.8},
#      'expectedAssists': 0.0124752}},
#    {'player': {'name': 'Sávio',
#      'firstName': 'Sávio',
#      'lastName': '',
#      'slug': 'savio',
#      'shortName': 'Sávio',
#      'position': 'M',
#      'jerseyNumber': '16',
#      'userCount': 5695,
#      'id': 1046795,
#      'country': {'alpha2': 'BR', 'name': 'Brazil'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1081555200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'سافيو'},
#       'shortNameTranslation': {'ar': 'سافيو'}}},
#     'shirtNumber': 16,
#     'jerseyNumber': '16',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 23,
#      'accuratePass': 19,
#      'totalLongBalls': 2,
#      'accurateLongBalls': 2,
#      'totalCross': 3,
#      'aerialLost': 2,
#      'aerialWon': 1,
#      'duelLost': 12,
#      'duelWon': 11,
#      'dispossessed': 3,
#      'totalContest': 7,
#      'wonContest': 2,
#      'shotOffTarget': 1,
#      'totalClearance': 1,
#      'totalTackle': 5,
#      'wasFouled': 3,
#      'fouls': 2,
#      'totalOffside': 1,
#      'minutesPlayed': 90,
#      'touches': 52,
#      'rating': 7.1,
#      'possessionLostCtrl': 18,
#      'expectedGoals': 0.0342,
#      'keyPass': 3,
#      'ratingVersions': {'original': 7.1, 'alternative': 7},
#      'expectedAssists': 0.157888}},
#    {'player': {'name': 'Portu',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'portu',
#      'shortName': 'Portu',
#      'position': 'M',
#      'jerseyNumber': '24',
#      'userCount': 898,
#      'id': 218616,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 706406400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بورتو'},
#       'shortNameTranslation': {'ar': 'بورتو'}}},
#     'shirtNumber': 24,
#     'jerseyNumber': '24',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'totalPass': 6,
#      'accuratePass': 6,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'duelWon': 1,
#      'totalTackle': 1,
#      'totalOffside': 3,
#      'minutesPlayed': 70,
#      'touches': 11,
#      'rating': 6.6,
#      'possessionLostCtrl': 1,
#      'ratingVersions': {'original': 6.6, 'alternative': 6.5},
#      'expectedAssists': 0.0184663}},
#    {'player': {'name': 'Pablo Torre',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'pablo-torre',
#      'shortName': 'P. Torre',
#      'position': 'M',
#      'jerseyNumber': '18',
#      'userCount': 6990,
#      'id': 1082981,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1049328000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'توري كارال ، بابلو'},
#       'shortNameTranslation': {'ar': 'ت. ك. ، بابلو'}}},
#     'shirtNumber': 18,
#     'jerseyNumber': '18',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'totalPass': 5,
#      'accuratePass': 5,
#      'duelWon': 1,
#      'totalTackle': 1,
#      'minutesPlayed': 20,
#      'touches': 7,
#      'rating': 6.6,
#      'possessionLostCtrl': 1,
#      'ratingVersions': {'original': 6.6, 'alternative': 6.6}}},
#    {'player': {'name': 'Cristhian Stuani',
#      'slug': 'cristhian-stuani',
#      'shortName': 'C. Stuani',
#      'position': 'F',
#      'jerseyNumber': '7',
#      'userCount': 1991,
#      'id': 32048,
#      'country': {'alpha2': 'UY', 'name': 'Uruguay'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 529459200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان ستواني'},
#       'shortNameTranslation': {'ar': 'ك. ستواني'}}},
#     'shirtNumber': 7,
#     'jerseyNumber': '7',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'totalPass': 4,
#      'accuratePass': 2,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'totalClearance': 2,
#      'outfielderBlock': 1,
#      'minutesPlayed': 20,
#      'touches': 11,
#      'rating': 6.7,
#      'possessionLostCtrl': 4,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6}}},
#    {'player': {'name': 'Valery Fernández',
#      'slug': 'valery-fernandez',
#      'shortName': 'V. Fernández',
#      'position': 'D',
#      'jerseyNumber': '11',
#      'userCount': 360,
#      'id': 962378,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 943315200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فرنانديز ، فاليري'},
#       'shortNameTranslation': {'ar': 'ف. ، فاليري'}}},
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {'totalPass': 3,
#      'accuratePass': 2,
#      'totalCross': 1,
#      'aerialWon': 1,
#      'duelWon': 3,
#      'bigChanceMissed': 1,
#      'shotOffTarget': 1,
#      'totalTackle': 1,
#      'wasFouled': 1,
#      'minutesPlayed': 10,
#      'touches': 8,
#      'rating': 6.7,
#      'possessionLostCtrl': 3,
#      'expectedGoals': 0.1904,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6}}},
#    {'player': {'name': 'Jhon Solís',
#      'firstName': 'Jhon Solis',
#      'slug': 'jhon-solis',
#      'shortName': 'J. Solís',
#      'position': 'M',
#      'jerseyNumber': '22',
#      'userCount': 793,
#      'id': 1106573,
#      'country': {'alpha2': 'CO', 'name': 'Colombia'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1096761600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'Solis, Jhon Elmer'},
#       'shortNameTranslation': {'ar': 'J. E. Solis'}}},
#     'shirtNumber': 22,
#     'jerseyNumber': '22',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'totalPass': 11,
#      'accuratePass': 10,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 1,
#      'duelWon': 3,
#      'totalContest': 2,
#      'wonContest': 2,
#      'interceptionWon': 1,
#      'minutesPlayed': 10,
#      'touches': 14,
#      'rating': 6.9,
#      'possessionLostCtrl': 1,
#      'expectedGoals': 0.024,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.9},
#      'expectedAssists': 0.0104714}},
#    {'player': {'name': 'Toni Fuidias',
#      'slug': 'toni-fuidias',
#      'shortName': 'T. Fuidias',
#      'position': 'G',
#      'jerseyNumber': '26',
#      'userCount': 460,
#      'id': 991960,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 987292800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فيدياس ريبيرا ، طوني'},
#       'shortNameTranslation': {'ar': 'ف. ر. ، طوني'}}},
#     'shirtNumber': 26,
#     'jerseyNumber': '26',
#     'position': 'G',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Arnau Martínez',
#      'firstName': 'Arnau Martinez',
#      'slug': 'arnau-martinez',
#      'shortName': 'A. Martínez',
#      'position': 'D',
#      'jerseyNumber': '4',
#      'userCount': 1471,
#      'id': 1084081,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1051228800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أرناو ، مارتينيز'},
#       'shortNameTranslation': {'ar': 'أ. ، مارتينيز'}}},
#     'shirtNumber': 4,
#     'jerseyNumber': '4',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Antal Yaakobishvili',
#      'slug': 'yaakobishvili-antal',
#      'shortName': 'A. Yaakobishvili',
#      'position': 'D',
#      'jerseyNumber': '35',
#      'userCount': 740,
#      'id': 1471513,
#      'country': {'alpha2': 'HU', 'name': 'Hungary'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1089590400},
#     'shirtNumber': 35,
#     'jerseyNumber': '35',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Juanpe',
#      'slug': 'juanpe',
#      'shortName': 'Juanpe',
#      'position': 'D',
#      'jerseyNumber': '15',
#      'userCount': 212,
#      'id': 129861,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 672969600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'خوانبي'},
#       'shortNameTranslation': {'ar': 'خوانبي'}}},
#     'shirtNumber': 15,
#     'jerseyNumber': '15',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Borja García',
#      'slug': 'borja-garcia',
#      'shortName': 'B. García',
#      'position': 'M',
#      'jerseyNumber': '10',
#      'userCount': 207,
#      'id': 129472,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 657504000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بورخا'},
#       'shortNameTranslation': {'ar': 'بورخا'}}},
#     'shirtNumber': 10,
#     'jerseyNumber': '10',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Ricard Artero',
#      'firstName': 'Ricard Artero',
#      'lastName': '',
#      'slug': 'ricard-artero',
#      'shortName': 'R. Artero',
#      'position': 'M',
#      'jerseyNumber': '36',
#      'userCount': 38,
#      'id': 1134432,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1044403200},
#     'shirtNumber': 36,
#     'jerseyNumber': '36',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}}],
#   'supportStaff': [],
#   'formation': '4-2-3-1',
#   'playerColor': {'primary': 'ff0000',
#    'number': 'ffffff',
#    'outline': 'ff0000',
#    'fancyNumber': 'ffffff'},
#   'goalkeeperColor': {'primary': '57beff',
#    'number': 'ffffff',
#    'outline': '57beff',
#    'fancyNumber': '222226'},
#   'missingPlayers': [{'player': {'name': 'Toni Villa',
#      'slug': 'toni-villa',
#      'shortName': 'Toni',
#      'position': 'M',
#      'jerseyNumber': '12',
#      'userCount': 198,
#      'id': 813523,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 789436800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فييا, توني'},
#       'shortNameTranslation': {'ar': 'ت. فييا'}}},
#     'type': 'missing',
#     'reason': 1},
#    {'player': {'name': 'David López',
#      'slug': 'david-lopez',
#      'shortName': 'D. López',
#      'position': 'D',
#      'jerseyNumber': '5',
#      'userCount': 725,
#      'id': 135116,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 623894400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'لوبيز, دافيد'},
#       'shortNameTranslation': {'ar': 'د. لوبيز'}}},
#     'type': 'missing',
#     'reason': 1}]},
#  'away': {'players': [{'player': {'name': 'Álex Remiro',
#      'slug': 'alex-remiro',
#      'shortName': 'Á. Remiro',
#      'position': 'G',
#      'jerseyNumber': '1',
#      'userCount': 941,
#      'id': 791773,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 796003200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ريميرو, أليكس'},
#       'shortNameTranslation': {'ar': 'أ. ريميرو'}}},
#     'shirtNumber': 1,
#     'jerseyNumber': '1',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'totalPass': 32,
#      'accuratePass': 28,
#      'totalLongBalls': 9,
#      'accurateLongBalls': 5,
#      'savedShotsFromInsideTheBox': 2,
#      'saves': 3,
#      'minutesPlayed': 90,
#      'touches': 37,
#      'rating': 7.3,
#      'possessionLostCtrl': 4,
#      'ratingVersions': {'original': 7.3, 'alternative': 7.4},
#      'goalsPrevented': 0.4932}},
#    {'player': {'name': 'Álvaro Odriozola',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'alvaro-odriozola',
#      'shortName': 'Á. Odriozola',
#      'position': 'D',
#      'jerseyNumber': '2',
#      'userCount': 3774,
#      'id': 353250,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 818899200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أودريوزولا, ألفارو'},
#       'shortNameTranslation': {'ar': 'أ. أودريوزولا'}}},
#     'shirtNumber': 2,
#     'jerseyNumber': '2',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalClearance': 1, 'minutesPlayed': 3, 'touches': 1}},
#    {'player': {'name': 'Igor Zubeldia',
#      'slug': 'igor-zubeldia',
#      'shortName': 'I. Zubeldia',
#      'position': 'D',
#      'jerseyNumber': '5',
#      'userCount': 658,
#      'id': 838159,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 859680000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'زوبيلديا, إيجور'},
#       'shortNameTranslation': {'ar': 'إ. زوبيلديا'}}},
#     'shirtNumber': 5,
#     'jerseyNumber': '5',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 60,
#      'accuratePass': 50,
#      'totalLongBalls': 8,
#      'accurateLongBalls': 4,
#      'aerialLost': 2,
#      'aerialWon': 2,
#      'duelLost': 3,
#      'duelWon': 2,
#      'shotOffTarget': 1,
#      'totalClearance': 4,
#      'outfielderBlock': 1,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 66,
#      'rating': 7.3,
#      'possessionLostCtrl': 10,
#      'expectedGoals': 0.1078,
#      'keyPass': 2,
#      'ratingVersions': {'original': 7.3, 'alternative': 7.2},
#      'expectedAssists': 0.0321423}},
#    {'player': {'name': 'Jon Pacheco',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'jon-pacheco',
#      'shortName': 'J. Pacheco',
#      'position': 'D',
#      'jerseyNumber': '20',
#      'userCount': 238,
#      'id': 934383,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 978912000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جون باتشيكو'},
#       'shortNameTranslation': {'ar': 'ج. باتشيكو'}}},
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 65,
#      'accuratePass': 63,
#      'totalLongBalls': 8,
#      'accurateLongBalls': 6,
#      'aerialWon': 3,
#      'duelLost': 1,
#      'duelWon': 4,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 2,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 74,
#      'rating': 7.3,
#      'possessionLostCtrl': 5,
#      'expectedGoals': 0.0697,
#      'ratingVersions': {'original': 7.3, 'alternative': 7.2},
#      'expectedAssists': 0.00821221}},
#    {'player': {'name': 'Javi Galán',
#      'slug': 'javi-galan',
#      'shortName': 'J. Galán',
#      'position': 'D',
#      'jerseyNumber': '25',
#      'userCount': 1231,
#      'id': 825133,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 785203200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'خافيير جالان جيل'},
#       'shortNameTranslation': {'ar': 'خ. ج. جيل'}}},
#     'shirtNumber': 25,
#     'jerseyNumber': '25',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 32,
#      'accuratePass': 27,
#      'totalLongBalls': 2,
#      'totalCross': 4,
#      'accurateCross': 1,
#      'aerialWon': 1,
#      'duelLost': 5,
#      'duelWon': 10,
#      'challengeLost': 2,
#      'dispossessed': 1,
#      'totalContest': 3,
#      'wonContest': 1,
#      'totalClearance': 2,
#      'interceptionWon': 1,
#      'totalTackle': 7,
#      'wasFouled': 1,
#      'minutesPlayed': 90,
#      'touches': 62,
#      'rating': 7.1,
#      'possessionLostCtrl': 12,
#      'ratingVersions': {'original': 7.1, 'alternative': 7.3},
#      'expectedAssists': 0.0501653}},
#    {'player': {'name': 'Sheraldo Becker',
#      'slug': 'sheraldo-becker',
#      'shortName': 'S. Becker',
#      'position': 'F',
#      'jerseyNumber': '11',
#      'userCount': 1613,
#      'id': 352544,
#      'country': {'alpha2': 'SR', 'name': 'Suriname'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 792288000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'شيرالدو بيكر'},
#       'shortNameTranslation': {'ar': 'ش. بيكر'}}},
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 12,
#      'accuratePass': 8,
#      'totalCross': 2,
#      'aerialLost': 2,
#      'duelLost': 4,
#      'dispossessed': 1,
#      'shotOffTarget': 1,
#      'fouls': 1,
#      'minutesPlayed': 52,
#      'touches': 19,
#      'rating': 6.5,
#      'possessionLostCtrl': 9,
#      'expectedGoals': 0.0454,
#      'ratingVersions': {'original': 6.5, 'alternative': 6.4},
#      'expectedAssists': 0.00660582}},
#    {'player': {'name': 'Beñat Turrientes',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'benat-turrientes',
#      'shortName': 'B. Turrientes',
#      'position': 'M',
#      'jerseyNumber': '22',
#      'userCount': 364,
#      'id': 980410,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1012435200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بينيات تورينتيس'},
#       'shortNameTranslation': {'ar': 'ب. تورينتيس'}}},
#     'shirtNumber': 22,
#     'jerseyNumber': '22',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 20,
#      'accuratePass': 19,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 3,
#      'totalCross': 1,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 5,
#      'duelWon': 3,
#      'challengeLost': 1,
#      'totalContest': 1,
#      'wonContest': 1,
#      'totalClearance': 1,
#      'totalTackle': 1,
#      'fouls': 3,
#      'minutesPlayed': 52,
#      'touches': 27,
#      'rating': 6.7,
#      'possessionLostCtrl': 4,
#      'keyPass': 1,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6},
#      'expectedAssists': 0.0133604}},
#    {'player': {'name': 'Martín Zubimendi',
#      'slug': 'martin-zubimendi',
#      'shortName': 'M. Zubimendi',
#      'position': 'M',
#      'jerseyNumber': '4',
#      'userCount': 2502,
#      'id': 966837,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 917913600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'مارتن زوبيمندي'},
#       'shortNameTranslation': {'ar': 'م. زوبيمندي'}}},
#     'shirtNumber': 4,
#     'jerseyNumber': '4',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 54,
#      'accuratePass': 53,
#      'totalLongBalls': 2,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialLost': 2,
#      'aerialWon': 1,
#      'duelLost': 6,
#      'duelWon': 1,
#      'dispossessed': 1,
#      'totalClearance': 2,
#      'interceptionWon': 2,
#      'fouls': 3,
#      'minutesPlayed': 90,
#      'touches': 66,
#      'rating': 6.7,
#      'possessionLostCtrl': 5,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6},
#      'expectedAssists': 0.0102803}},
#    {'player': {'name': 'Mikel Oyarzabal',
#      'slug': 'mikel-oyarzabal',
#      'shortName': 'M. Oyarzabal',
#      'position': 'F',
#      'jerseyNumber': '10',
#      'userCount': 4500,
#      'id': 823622,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 861580800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أويارزابال, ميكيل'},
#       'shortNameTranslation': {'ar': 'م. أويارزابال'}}},
#     'shirtNumber': 10,
#     'jerseyNumber': '10',
#     'position': 'M',
#     'substitute': False,
#     'captain': True,
#     'statistics': {'totalPass': 31,
#      'accuratePass': 25,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 3,
#      'totalCross': 1,
#      'aerialLost': 1,
#      'aerialWon': 2,
#      'duelLost': 7,
#      'duelWon': 5,
#      'challengeLost': 1,
#      'dispossessed': 3,
#      'totalContest': 2,
#      'wonContest': 2,
#      'blockedScoringAttempt': 1,
#      'outfielderBlock': 1,
#      'totalTackle': 1,
#      'fouls': 2,
#      'totalOffside': 1,
#      'minutesPlayed': 89,
#      'touches': 45,
#      'rating': 6.9,
#      'possessionLostCtrl': 12,
#      'expectedGoals': 0.0332,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.7},
#      'expectedAssists': 0.0832798}},
#    {'player': {'name': 'Brais Méndez',
#      'slug': 'brais-mendez',
#      'shortName': 'B. Méndez',
#      'position': 'M',
#      'jerseyNumber': '23',
#      'userCount': 1967,
#      'id': 845385,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 852595200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'},
#       'shortNameTranslation': {'ar': 'ب. منديز'}}},
#     'shirtNumber': 23,
#     'jerseyNumber': '23',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'totalPass': 33,
#      'accuratePass': 25,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 1,
#      'totalCross': 6,
#      'accurateCross': 2,
#      'duelLost': 7,
#      'duelWon': 3,
#      'challengeLost': 1,
#      'dispossessed': 1,
#      'totalContest': 2,
#      'onTargetScoringAttempt': 1,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 1,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'wasFouled': 2,
#      'fouls': 3,
#      'minutesPlayed': 87,
#      'touches': 50,
#      'rating': 7.1,
#      'possessionLostCtrl': 16,
#      'expectedGoals': 0.1898,
#      'keyPass': 2,
#      'ratingVersions': {'original': 7.1, 'alternative': 7.1},
#      'expectedAssists': 0.29178}},
#    {'player': {'name': 'André Silva',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'andre-silva',
#      'shortName': 'A. Silva',
#      'position': 'F',
#      'jerseyNumber': '21',
#      'userCount': 6798,
#      'id': 190159,
#      'country': {'alpha2': 'PT', 'name': 'Portugal'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 815616000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'},
#       'shortNameTranslation': {'ar': 'أ. سيلفا'}}},
#     'shirtNumber': 21,
#     'jerseyNumber': '21',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'totalPass': 20,
#      'accuratePass': 17,
#      'aerialLost': 3,
#      'aerialWon': 3,
#      'duelLost': 12,
#      'duelWon': 6,
#      'challengeLost': 1,
#      'dispossessed': 5,
#      'totalContest': 1,
#      'shotOffTarget': 2,
#      'onTargetScoringAttempt': 1,
#      'totalClearance': 1,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'wasFouled': 2,
#      'fouls': 3,
#      'minutesPlayed': 87,
#      'touches': 43,
#      'rating': 6.8,
#      'possessionLostCtrl': 13,
#      'expectedGoals': 0.11,
#      'keyPass': 1,
#      'ratingVersions': {'original': 6.8, 'alternative': 6.7},
#      'expectedAssists': 0.0350007}},
#    {'player': {'name': 'Jon Aramburu',
#      'firstName': 'Jon Aramburu',
#      'lastName': '',
#      'slug': 'jon-aramburu',
#      'shortName': 'J. Aramburu',
#      'position': 'M',
#      'jerseyNumber': '39',
#      'userCount': 343,
#      'id': 1116388,
#      'country': {'alpha2': 'VE', 'name': 'Venezuela'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1027382400},
#     'shirtNumber': 39,
#     'jerseyNumber': '39',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {'totalPass': 33,
#      'accuratePass': 28,
#      'totalLongBalls': 4,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialWon': 1,
#      'duelLost': 3,
#      'duelWon': 6,
#      'challengeLost': 1,
#      'dispossessed': 1,
#      'totalContest': 1,
#      'shotOffTarget': 1,
#      'totalClearance': 2,
#      'interceptionWon': 1,
#      'totalTackle': 4,
#      'wasFouled': 1,
#      'minutesPlayed': 87,
#      'touches': 57,
#      'rating': 6.9,
#      'possessionLostCtrl': 13,
#      'expectedGoals': 0.0174,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.8},
#      'expectedAssists': 0.0107032}},
#    {'player': {'name': 'Mikel Merino',
#      'slug': 'mikel-merino',
#      'shortName': 'M. Merino',
#      'position': 'M',
#      'jerseyNumber': '8',
#      'userCount': 2036,
#      'id': 592010,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 835401600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ميرينو, ميكيل'},
#       'shortNameTranslation': {'ar': 'م. ميرينو'}}},
#     'shirtNumber': 8,
#     'jerseyNumber': '8',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'totalPass': 25,
#      'accuratePass': 21,
#      'aerialLost': 3,
#      'duelLost': 8,
#      'duelWon': 1,
#      'challengeLost': 2,
#      'dispossessed': 1,
#      'totalContest': 1,
#      'totalClearance': 1,
#      'outfielderBlock': 2,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'fouls': 1,
#      'minutesPlayed': 38,
#      'touches': 36,
#      'rating': 6.7,
#      'possessionLostCtrl': 7,
#      'keyPass': 2,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6},
#      'expectedAssists': 0.0118951}},
#    {'player': {'name': 'Ander Barrenetxea',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'ander-barrenetxea',
#      'shortName': 'A. Barrenetxea',
#      'position': 'F',
#      'jerseyNumber': '7',
#      'userCount': 1229,
#      'id': 966862,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1009411200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بارنيتكسيا, أندر'},
#       'shortNameTranslation': {'ar': 'أ. بارنيتكسيا'}}},
#     'shirtNumber': 7,
#     'jerseyNumber': '7',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'totalPass': 9,
#      'accuratePass': 4,
#      'totalLongBalls': 1,
#      'totalCross': 4,
#      'accurateCross': 1,
#      'aerialWon': 2,
#      'duelLost': 3,
#      'duelWon': 11,
#      'dispossessed': 1,
#      'totalContest': 2,
#      'wonContest': 1,
#      'blockedScoringAttempt': 1,
#      'outfielderBlock': 1,
#      'totalTackle': 6,
#      'wasFouled': 2,
#      'fouls': 1,
#      'minutesPlayed': 38,
#      'touches': 33,
#      'rating': 7.4,
#      'possessionLostCtrl': 13,
#      'expectedGoals': 0.03,
#      'ratingVersions': {'original': 7.4, 'alternative': 7.1},
#      'expectedAssists': 0.00573558}},
#    {'player': {'name': 'Jon Ander Olasagasti',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'jon-ander-olasagasti',
#      'shortName': 'J. A. Olasagasti',
#      'position': 'M',
#      'jerseyNumber': '16',
#      'userCount': 93,
#      'id': 1010383,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 966384000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جون أندر أولاساغاستي'},
#       'shortNameTranslation': {'ar': 'ج. أ. أولاساغاستي'}}},
#     'shirtNumber': 16,
#     'jerseyNumber': '16',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'minutesPlayed': 10,
#      'rating': 6.5,
#      'ratingVersions': {'original': 6.5, 'alternative': 6.5}}},
#    {'player': {'name': 'Umar Sadiq',
#      'slug': 'umar-sadiq',
#      'shortName': 'U. Sadiq',
#      'position': 'F',
#      'jerseyNumber': '19',
#      'userCount': 2317,
#      'id': 754710,
#      'country': {'alpha2': 'NG', 'name': 'Nigeria'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 854841600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'عمر صادق'},
#       'shortNameTranslation': {'ar': 'ع. صادق'}}},
#     'shirtNumber': 19,
#     'jerseyNumber': '19',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'totalPass': 1,
#      'accuratePass': 1,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'totalClearance': 1,
#      'totalOffside': 1,
#      'minutesPlayed': 10,
#      'touches': 2,
#      'rating': 6.5,
#      'ratingVersions': {'original': 6.5, 'alternative': 6.5}}},
#    {'player': {'name': 'Unai Marrero',
#      'firstName': 'Unai Marrero',
#      'lastName': '',
#      'slug': 'unai-marrero',
#      'shortName': 'U. Marrero',
#      'position': 'G',
#      'jerseyNumber': '13',
#      'userCount': 92,
#      'id': 1094782,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1002585600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ماريرو ، أوناي'},
#       'shortNameTranslation': {'ar': 'م. ، أوناي'}}},
#     'shirtNumber': 13,
#     'jerseyNumber': '13',
#     'position': 'G',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Robin Le Normand',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'robin-le-normand',
#      'shortName': 'R. Le Normand',
#      'position': 'D',
#      'jerseyNumber': '24',
#      'userCount': 1304,
#      'id': 787751,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 847670400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'لو نورماند, روبين'},
#       'shortNameTranslation': {'ar': 'ر. ل. نورماند'}}},
#     'shirtNumber': 24,
#     'jerseyNumber': '24',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Jon Martin Vicente',
#      'firstName': 'Jon Martín',
#      'slug': 'vicente-jon-martin',
#      'shortName': 'J. Martín',
#      'position': 'D',
#      'jerseyNumber': '36',
#      'userCount': 136,
#      'id': 1466116,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1145750400},
#     'shirtNumber': 36,
#     'jerseyNumber': '36',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Iñaki Rupérez Urtasun',
#      'slug': 'inaki-ruperez-urtasun',
#      'shortName': 'I. R. Urtasun',
#      'position': 'D',
#      'jerseyNumber': '41',
#      'userCount': 7,
#      'id': 1526573,
#      'country': {},
#      'marketValueCurrency': 'EUR'},
#     'shirtNumber': 41,
#     'jerseyNumber': '41',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Urko González',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'urko-gonzalez',
#      'shortName': 'U. González',
#      'position': 'D',
#      'jerseyNumber': '15',
#      'userCount': 79,
#      'id': 1064009,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 985046400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أوركو جونزاليس'},
#       'shortNameTranslation': {'ar': 'أ. جونزاليس'}}},
#     'shirtNumber': 15,
#     'jerseyNumber': '15',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Jon Magunazelaia',
#      'firstName': 'Jon Magunacelaya',
#      'lastName': '',
#      'slug': 'jon-magunazelaia',
#      'shortName': 'J. Magunazelaia',
#      'position': 'M',
#      'jerseyNumber': '28',
#      'userCount': 37,
#      'id': 1134396,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 994982400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ماجوناسيلايا ، جون'},
#       'shortNameTranslation': {'ar': 'م. ، جون'}}},
#     'shirtNumber': 28,
#     'jerseyNumber': '28',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Arsen Zakharyan',
#      'firstName': 'Arsen Zakharyan',
#      'slug': 'arsen-zakharyan',
#      'shortName': 'A. Zakharyan',
#      'position': 'M',
#      'jerseyNumber': '12',
#      'userCount': 3672,
#      'id': 1066045,
#      'country': {'alpha2': 'RU', 'name': 'Russia'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1053907200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أرسين زاخاريان'},
#       'shortNameTranslation': {'ar': 'أ. زاخاريان'}}},
#     'shirtNumber': 12,
#     'jerseyNumber': '12',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}}],
#   'supportStaff': [],
#   'formation': '4-4-1-1',
#   'playerColor': {'primary': '2a3a57',
#    'number': 'ffffff',
#    'outline': '2a3a57',
#    'fancyNumber': 'ffffff'},
#   'goalkeeperColor': {'primary': '25ff00',
#    'number': 'ffffff',
#    'outline': '25ff00',
#    'fancyNumber': '222226'},
#   'missingPlayers': [{'player': {'name': 'Martín Merquelanz',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'martin-merquelanz',
#      'shortName': 'M. Merquelanz',
#      'position': 'F',
#      'jerseyNumber': '99',
#      'userCount': 181,
#      'id': 353252,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 802915200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ميركيلانز, مارتين'},
#       'shortNameTranslation': {'ar': 'م. ميركيلانز'}}},
#     'type': 'missing',
#     'reason': 1},
#    {'player': {'name': 'Hamari Traoré',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'hamari-traore',
#      'shortName': 'H. Traoré',
#      'position': 'D',
#      'jerseyNumber': '18',
#      'userCount': 2513,
#      'id': 362014,
#      'country': {'alpha2': 'ML', 'name': 'Mali'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 696470400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'هاماري تراوري'},
#       'shortNameTranslation': {'ar': 'ه. تراوري'}}},
#     'type': 'missing',
#     'reason': 0},
#    {'player': {'name': 'Takefusa Kubo',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'kubo-takefusa',
#      'shortName': 'T. Kubo',
#      'position': 'M',
#      'jerseyNumber': '14',
#      'userCount': 16838,
#      'id': 880218,
#      'country': {'alpha2': 'JP', 'name': 'Japan'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 991612800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'تاكيفوسا كوبو'},
#       'shortNameTranslation': {'ar': 'ت. كوبو'}}},
#     'type': 'missing',
#     'reason': 0}]}}

# %%
len(pstats)
#home,away,confirmed
# Out:
# 3

# %%
pstats
# Out:
# {'confirmed': True,
#  'home': {'players': [{'player': {'name': 'Paulo Gazzaniga',
#      'slug': 'paulo-gazzaniga',
#      'shortName': 'P. Gazzaniga',
#      'position': 'G',
#      'jerseyNumber': '13',
#      'userCount': 1680,
#      'id': 164343,
#      'country': {'alpha2': 'AR', 'name': 'Argentina'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 694310400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'غازانيجا, باولو'},
#       'shortNameTranslation': {'ar': 'ب. غازانيجا'}}},
#     'shirtNumber': 13,
#     'jerseyNumber': '13',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'totalPass': 45,
#      'accuratePass': 26,
#      'totalLongBalls': 27,
#      'accurateLongBalls': 9,
#      'savedShotsFromInsideTheBox': 1,
#      'saves': 2,
#      'minutesPlayed': 90,
#      'touches': 51,
#      'rating': 7,
#      'possessionLostCtrl': 21,
#      'ratingVersions': {'original': 7, 'alternative': 7.3},
#      'goalsPrevented': 0.1831}},
#    {'player': {'name': 'Yan Couto',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'couto-yan',
#      'shortName': 'Y. Couto',
#      'position': 'M',
#      'jerseyNumber': '20',
#      'userCount': 3412,
#      'id': 1002813,
#      'country': {'alpha2': 'BR', 'name': 'Brazil'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1023062400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'يان كوتو'},
#       'shortNameTranslation': {'ar': 'ي. كوتو'}}},
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 52,
#      'accuratePass': 44,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 3,
#      'totalCross': 1,
#      'accurateCross': 1,
#      'aerialLost': 1,
#      'duelLost': 11,
#      'duelWon': 6,
#      'dispossessed': 4,
#      'totalContest': 8,
#      'wonContest': 3,
#      'bigChanceCreated': 1,
#      'totalTackle': 1,
#      'wasFouled': 2,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 83,
#      'rating': 6.8,
#      'possessionLostCtrl': 20,
#      'keyPass': 2,
#      'ratingVersions': {'original': 6.8, 'alternative': 6.7},
#      'expectedAssists': 0.195063}},
#    {'player': {'name': 'Eric García',
#      'slug': 'eric-garcia',
#      'shortName': 'E. García',
#      'position': 'D',
#      'jerseyNumber': '25',
#      'userCount': 8185,
#      'id': 876214,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 978998400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, اريك'},
#       'shortNameTranslation': {'ar': 'ا. جارسيا'}}},
#     'shirtNumber': 25,
#     'jerseyNumber': '25',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 52,
#      'accuratePass': 47,
#      'totalLongBalls': 4,
#      'accurateLongBalls': 3,
#      'aerialLost': 1,
#      'aerialWon': 2,
#      'duelLost': 2,
#      'duelWon': 6,
#      'totalClearance': 5,
#      'interceptionWon': 1,
#      'totalTackle': 3,
#      'wasFouled': 1,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 63,
#      'rating': 7.5,
#      'possessionLostCtrl': 5,
#      'ratingVersions': {'original': 7.5, 'alternative': 7.6},
#      'expectedAssists': 0.137272}},
#    {'player': {'name': 'Daley Blind',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'daley-blind',
#      'shortName': 'D. Blind',
#      'position': 'D',
#      'jerseyNumber': '17',
#      'userCount': 3766,
#      'id': 44864,
#      'country': {'alpha2': 'NL', 'name': 'Netherlands'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 636940800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'},
#       'shortNameTranslation': {'ar': 'د. بلايند'}}},
#     'shirtNumber': 17,
#     'jerseyNumber': '17',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 60,
#      'accuratePass': 54,
#      'totalLongBalls': 2,
#      'totalCross': 1,
#      'aerialLost': 2,
#      'aerialWon': 4,
#      'duelLost': 3,
#      'duelWon': 4,
#      'challengeLost': 1,
#      'shotOffTarget': 1,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 4,
#      'minutesPlayed': 90,
#      'touches': 73,
#      'rating': 6.9,
#      'possessionLostCtrl': 9,
#      'expectedGoals': 0.0709,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.9},
#      'expectedAssists': 0.00781402}},
#    {'player': {'name': 'Miguel Gutiérrez',
#      'slug': 'miguel-gutierrez',
#      'shortName': 'M. Gutiérrez',
#      'position': 'D',
#      'jerseyNumber': '3',
#      'userCount': 2755,
#      'id': 908716,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 996192000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جوتيريز ، ميغيل'},
#       'shortNameTranslation': {'ar': 'ج. ، ميغيل'}}},
#     'shirtNumber': 3,
#     'jerseyNumber': '3',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 35,
#      'accuratePass': 32,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 2,
#      'duelWon': 2,
#      'dispossessed': 1,
#      'totalContest': 1,
#      'wonContest': 1,
#      'blockedScoringAttempt': 1,
#      'outfielderBlock': 2,
#      'minutesPlayed': 90,
#      'touches': 51,
#      'rating': 7.2,
#      'possessionLostCtrl': 6,
#      'expectedGoals': 0.0556,
#      'keyPass': 1,
#      'ratingVersions': {'original': 7.2, 'alternative': 7.1},
#      'expectedAssists': 0.0363362}},
#    {'player': {'name': 'Yangel Herrera',
#      'slug': 'yangel-herrera',
#      'shortName': 'Y. Herrera',
#      'position': 'M',
#      'jerseyNumber': '21',
#      'userCount': 2365,
#      'id': 839585,
#      'country': {'alpha2': 'VE', 'name': 'Venezuela'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 884131200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'},
#       'shortNameTranslation': {'ar': 'ي. هيريرا'}}},
#     'shirtNumber': 21,
#     'jerseyNumber': '21',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 26,
#      'accuratePass': 22,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialLost': 4,
#      'aerialWon': 4,
#      'duelLost': 11,
#      'duelWon': 15,
#      'challengeLost': 3,
#      'dispossessed': 2,
#      'totalContest': 1,
#      'wonContest': 1,
#      'onTargetScoringAttempt': 1,
#      'blockedScoringAttempt': 2,
#      'totalClearance': 1,
#      'interceptionWon': 1,
#      'totalTackle': 4,
#      'wasFouled': 6,
#      'fouls': 2,
#      'minutesPlayed': 90,
#      'touches': 53,
#      'rating': 7.4,
#      'possessionLostCtrl': 9,
#      'expectedGoals': 0.1257,
#      'ratingVersions': {'original': 7.4, 'alternative': 7.1},
#      'expectedAssists': 0.00849824}},
#    {'player': {'name': 'Aleix García',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'aleix-garcia',
#      'shortName': 'A. García',
#      'position': 'M',
#      'jerseyNumber': '14',
#      'userCount': 2900,
#      'id': 796047,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 867456000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'},
#       'shortNameTranslation': {'ar': 'أ. جارسيا'}}},
#     'shirtNumber': 14,
#     'jerseyNumber': '14',
#     'position': 'M',
#     'substitute': False,
#     'captain': True,
#     'statistics': {'totalPass': 31,
#      'accuratePass': 28,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'duelLost': 1,
#      'duelWon': 5,
#      'onTargetScoringAttempt': 1,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 1,
#      'totalTackle': 3,
#      'errorLeadToAShot': 1,
#      'wasFouled': 2,
#      'fouls': 1,
#      'minutesPlayed': 80,
#      'touches': 44,
#      'rating': 7,
#      'possessionLostCtrl': 5,
#      'expectedGoals': 0.1655,
#      'keyPass': 1,
#      'ratingVersions': {'original': 7, 'alternative': 7},
#      'expectedAssists': 0.0613259}},
#    {'player': {'name': 'Viktor Tsygankov',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'viktor-tsygankov',
#      'shortName': 'V. Tsygankov',
#      'position': 'M',
#      'jerseyNumber': '8',
#      'userCount': 4344,
#      'id': 319735,
#      'country': {'alpha2': 'UA', 'name': 'Ukraine'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 879552000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فيكتور تسيغانكوف'},
#       'shortNameTranslation': {'ar': 'ف. تسيغانكوف'}}},
#     'shirtNumber': 8,
#     'jerseyNumber': '8',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 23,
#      'accuratePass': 16,
#      'totalLongBalls': 1,
#      'totalCross': 2,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 6,
#      'duelWon': 4,
#      'challengeLost': 1,
#      'dispossessed': 3,
#      'onTargetScoringAttempt': 1,
#      'totalClearance': 5,
#      'totalTackle': 3,
#      'fouls': 1,
#      'minutesPlayed': 80,
#      'touches': 40,
#      'rating': 6.9,
#      'possessionLostCtrl': 12,
#      'expectedGoals': 0.0782,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.6},
#      'expectedAssists': 0.0195499}},
#    {'player': {'name': 'Iván Martín',
#      'slug': 'ivan-martin',
#      'shortName': 'I. Martín',
#      'position': 'M',
#      'jerseyNumber': '23',
#      'userCount': 781,
#      'id': 973699,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 918950400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'مارتن, إيفان'},
#       'shortNameTranslation': {'ar': 'إ. مارتن'}}},
#     'shirtNumber': 23,
#     'jerseyNumber': '23',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 27,
#      'accuratePass': 23,
#      'totalLongBalls': 1,
#      'accurateLongBalls': 1,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'duelWon': 4,
#      'totalTackle': 1,
#      'wasFouled': 3,
#      'minutesPlayed': 70,
#      'touches': 32,
#      'rating': 6.8,
#      'possessionLostCtrl': 4,
#      'ratingVersions': {'original': 6.8, 'alternative': 6.8},
#      'expectedAssists': 0.0124752}},
#    {'player': {'name': 'Sávio',
#      'firstName': 'Sávio',
#      'lastName': '',
#      'slug': 'savio',
#      'shortName': 'Sávio',
#      'position': 'M',
#      'jerseyNumber': '16',
#      'userCount': 5695,
#      'id': 1046795,
#      'country': {'alpha2': 'BR', 'name': 'Brazil'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1081555200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'سافيو'},
#       'shortNameTranslation': {'ar': 'سافيو'}}},
#     'shirtNumber': 16,
#     'jerseyNumber': '16',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 23,
#      'accuratePass': 19,
#      'totalLongBalls': 2,
#      'accurateLongBalls': 2,
#      'totalCross': 3,
#      'aerialLost': 2,
#      'aerialWon': 1,
#      'duelLost': 12,
#      'duelWon': 11,
#      'dispossessed': 3,
#      'totalContest': 7,
#      'wonContest': 2,
#      'shotOffTarget': 1,
#      'totalClearance': 1,
#      'totalTackle': 5,
#      'wasFouled': 3,
#      'fouls': 2,
#      'totalOffside': 1,
#      'minutesPlayed': 90,
#      'touches': 52,
#      'rating': 7.1,
#      'possessionLostCtrl': 18,
#      'expectedGoals': 0.0342,
#      'keyPass': 3,
#      'ratingVersions': {'original': 7.1, 'alternative': 7},
#      'expectedAssists': 0.157888}},
#    {'player': {'name': 'Portu',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'portu',
#      'shortName': 'Portu',
#      'position': 'M',
#      'jerseyNumber': '24',
#      'userCount': 898,
#      'id': 218616,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 706406400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بورتو'},
#       'shortNameTranslation': {'ar': 'بورتو'}}},
#     'shirtNumber': 24,
#     'jerseyNumber': '24',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'totalPass': 6,
#      'accuratePass': 6,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'duelWon': 1,
#      'totalTackle': 1,
#      'totalOffside': 3,
#      'minutesPlayed': 70,
#      'touches': 11,
#      'rating': 6.6,
#      'possessionLostCtrl': 1,
#      'ratingVersions': {'original': 6.6, 'alternative': 6.5},
#      'expectedAssists': 0.0184663}},
#    {'player': {'name': 'Pablo Torre',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'pablo-torre',
#      'shortName': 'P. Torre',
#      'position': 'M',
#      'jerseyNumber': '18',
#      'userCount': 6990,
#      'id': 1082981,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1049328000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'توري كارال ، بابلو'},
#       'shortNameTranslation': {'ar': 'ت. ك. ، بابلو'}}},
#     'shirtNumber': 18,
#     'jerseyNumber': '18',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'totalPass': 5,
#      'accuratePass': 5,
#      'duelWon': 1,
#      'totalTackle': 1,
#      'minutesPlayed': 20,
#      'touches': 7,
#      'rating': 6.6,
#      'possessionLostCtrl': 1,
#      'ratingVersions': {'original': 6.6, 'alternative': 6.6}}},
#    {'player': {'name': 'Cristhian Stuani',
#      'slug': 'cristhian-stuani',
#      'shortName': 'C. Stuani',
#      'position': 'F',
#      'jerseyNumber': '7',
#      'userCount': 1991,
#      'id': 32048,
#      'country': {'alpha2': 'UY', 'name': 'Uruguay'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 529459200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان ستواني'},
#       'shortNameTranslation': {'ar': 'ك. ستواني'}}},
#     'shirtNumber': 7,
#     'jerseyNumber': '7',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'totalPass': 4,
#      'accuratePass': 2,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'totalClearance': 2,
#      'outfielderBlock': 1,
#      'minutesPlayed': 20,
#      'touches': 11,
#      'rating': 6.7,
#      'possessionLostCtrl': 4,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6}}},
#    {'player': {'name': 'Valery Fernández',
#      'slug': 'valery-fernandez',
#      'shortName': 'V. Fernández',
#      'position': 'D',
#      'jerseyNumber': '11',
#      'userCount': 360,
#      'id': 962378,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 943315200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فرنانديز ، فاليري'},
#       'shortNameTranslation': {'ar': 'ف. ، فاليري'}}},
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {'totalPass': 3,
#      'accuratePass': 2,
#      'totalCross': 1,
#      'aerialWon': 1,
#      'duelWon': 3,
#      'bigChanceMissed': 1,
#      'shotOffTarget': 1,
#      'totalTackle': 1,
#      'wasFouled': 1,
#      'minutesPlayed': 10,
#      'touches': 8,
#      'rating': 6.7,
#      'possessionLostCtrl': 3,
#      'expectedGoals': 0.1904,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6}}},
#    {'player': {'name': 'Jhon Solís',
#      'firstName': 'Jhon Solis',
#      'slug': 'jhon-solis',
#      'shortName': 'J. Solís',
#      'position': 'M',
#      'jerseyNumber': '22',
#      'userCount': 793,
#      'id': 1106573,
#      'country': {'alpha2': 'CO', 'name': 'Colombia'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1096761600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'Solis, Jhon Elmer'},
#       'shortNameTranslation': {'ar': 'J. E. Solis'}}},
#     'shirtNumber': 22,
#     'jerseyNumber': '22',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'totalPass': 11,
#      'accuratePass': 10,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 1,
#      'duelWon': 3,
#      'totalContest': 2,
#      'wonContest': 2,
#      'interceptionWon': 1,
#      'minutesPlayed': 10,
#      'touches': 14,
#      'rating': 6.9,
#      'possessionLostCtrl': 1,
#      'expectedGoals': 0.024,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.9},
#      'expectedAssists': 0.0104714}},
#    {'player': {'name': 'Toni Fuidias',
#      'slug': 'toni-fuidias',
#      'shortName': 'T. Fuidias',
#      'position': 'G',
#      'jerseyNumber': '26',
#      'userCount': 460,
#      'id': 991960,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 987292800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فيدياس ريبيرا ، طوني'},
#       'shortNameTranslation': {'ar': 'ف. ر. ، طوني'}}},
#     'shirtNumber': 26,
#     'jerseyNumber': '26',
#     'position': 'G',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Arnau Martínez',
#      'firstName': 'Arnau Martinez',
#      'slug': 'arnau-martinez',
#      'shortName': 'A. Martínez',
#      'position': 'D',
#      'jerseyNumber': '4',
#      'userCount': 1471,
#      'id': 1084081,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1051228800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أرناو ، مارتينيز'},
#       'shortNameTranslation': {'ar': 'أ. ، مارتينيز'}}},
#     'shirtNumber': 4,
#     'jerseyNumber': '4',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Antal Yaakobishvili',
#      'slug': 'yaakobishvili-antal',
#      'shortName': 'A. Yaakobishvili',
#      'position': 'D',
#      'jerseyNumber': '35',
#      'userCount': 740,
#      'id': 1471513,
#      'country': {'alpha2': 'HU', 'name': 'Hungary'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1089590400},
#     'shirtNumber': 35,
#     'jerseyNumber': '35',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Juanpe',
#      'slug': 'juanpe',
#      'shortName': 'Juanpe',
#      'position': 'D',
#      'jerseyNumber': '15',
#      'userCount': 212,
#      'id': 129861,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 672969600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'خوانبي'},
#       'shortNameTranslation': {'ar': 'خوانبي'}}},
#     'shirtNumber': 15,
#     'jerseyNumber': '15',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Borja García',
#      'slug': 'borja-garcia',
#      'shortName': 'B. García',
#      'position': 'M',
#      'jerseyNumber': '10',
#      'userCount': 207,
#      'id': 129472,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 657504000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بورخا'},
#       'shortNameTranslation': {'ar': 'بورخا'}}},
#     'shirtNumber': 10,
#     'jerseyNumber': '10',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Ricard Artero',
#      'firstName': 'Ricard Artero',
#      'lastName': '',
#      'slug': 'ricard-artero',
#      'shortName': 'R. Artero',
#      'position': 'M',
#      'jerseyNumber': '36',
#      'userCount': 38,
#      'id': 1134432,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1044403200},
#     'shirtNumber': 36,
#     'jerseyNumber': '36',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}}],
#   'supportStaff': [],
#   'formation': '4-2-3-1',
#   'playerColor': {'primary': 'ff0000',
#    'number': 'ffffff',
#    'outline': 'ff0000',
#    'fancyNumber': 'ffffff'},
#   'goalkeeperColor': {'primary': '57beff',
#    'number': 'ffffff',
#    'outline': '57beff',
#    'fancyNumber': '222226'},
#   'missingPlayers': [{'player': {'name': 'Toni Villa',
#      'slug': 'toni-villa',
#      'shortName': 'Toni',
#      'position': 'M',
#      'jerseyNumber': '12',
#      'userCount': 198,
#      'id': 813523,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 789436800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'فييا, توني'},
#       'shortNameTranslation': {'ar': 'ت. فييا'}}},
#     'type': 'missing',
#     'reason': 1},
#    {'player': {'name': 'David López',
#      'slug': 'david-lopez',
#      'shortName': 'D. López',
#      'position': 'D',
#      'jerseyNumber': '5',
#      'userCount': 725,
#      'id': 135116,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 623894400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'لوبيز, دافيد'},
#       'shortNameTranslation': {'ar': 'د. لوبيز'}}},
#     'type': 'missing',
#     'reason': 1}]},
#  'away': {'players': [{'player': {'name': 'Álex Remiro',
#      'slug': 'alex-remiro',
#      'shortName': 'Á. Remiro',
#      'position': 'G',
#      'jerseyNumber': '1',
#      'userCount': 941,
#      'id': 791773,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 796003200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ريميرو, أليكس'},
#       'shortNameTranslation': {'ar': 'أ. ريميرو'}}},
#     'shirtNumber': 1,
#     'jerseyNumber': '1',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'totalPass': 32,
#      'accuratePass': 28,
#      'totalLongBalls': 9,
#      'accurateLongBalls': 5,
#      'savedShotsFromInsideTheBox': 2,
#      'saves': 3,
#      'minutesPlayed': 90,
#      'touches': 37,
#      'rating': 7.3,
#      'possessionLostCtrl': 4,
#      'ratingVersions': {'original': 7.3, 'alternative': 7.4},
#      'goalsPrevented': 0.4932}},
#    {'player': {'name': 'Álvaro Odriozola',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'alvaro-odriozola',
#      'shortName': 'Á. Odriozola',
#      'position': 'D',
#      'jerseyNumber': '2',
#      'userCount': 3774,
#      'id': 353250,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 818899200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أودريوزولا, ألفارو'},
#       'shortNameTranslation': {'ar': 'أ. أودريوزولا'}}},
#     'shirtNumber': 2,
#     'jerseyNumber': '2',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalClearance': 1, 'minutesPlayed': 3, 'touches': 1}},
#    {'player': {'name': 'Igor Zubeldia',
#      'slug': 'igor-zubeldia',
#      'shortName': 'I. Zubeldia',
#      'position': 'D',
#      'jerseyNumber': '5',
#      'userCount': 658,
#      'id': 838159,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 859680000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'زوبيلديا, إيجور'},
#       'shortNameTranslation': {'ar': 'إ. زوبيلديا'}}},
#     'shirtNumber': 5,
#     'jerseyNumber': '5',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 60,
#      'accuratePass': 50,
#      'totalLongBalls': 8,
#      'accurateLongBalls': 4,
#      'aerialLost': 2,
#      'aerialWon': 2,
#      'duelLost': 3,
#      'duelWon': 2,
#      'shotOffTarget': 1,
#      'totalClearance': 4,
#      'outfielderBlock': 1,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 66,
#      'rating': 7.3,
#      'possessionLostCtrl': 10,
#      'expectedGoals': 0.1078,
#      'keyPass': 2,
#      'ratingVersions': {'original': 7.3, 'alternative': 7.2},
#      'expectedAssists': 0.0321423}},
#    {'player': {'name': 'Jon Pacheco',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'jon-pacheco',
#      'shortName': 'J. Pacheco',
#      'position': 'D',
#      'jerseyNumber': '20',
#      'userCount': 238,
#      'id': 934383,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 978912000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جون باتشيكو'},
#       'shortNameTranslation': {'ar': 'ج. باتشيكو'}}},
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 65,
#      'accuratePass': 63,
#      'totalLongBalls': 8,
#      'accurateLongBalls': 6,
#      'aerialWon': 3,
#      'duelLost': 1,
#      'duelWon': 4,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 2,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'fouls': 1,
#      'minutesPlayed': 90,
#      'touches': 74,
#      'rating': 7.3,
#      'possessionLostCtrl': 5,
#      'expectedGoals': 0.0697,
#      'ratingVersions': {'original': 7.3, 'alternative': 7.2},
#      'expectedAssists': 0.00821221}},
#    {'player': {'name': 'Javi Galán',
#      'slug': 'javi-galan',
#      'shortName': 'J. Galán',
#      'position': 'D',
#      'jerseyNumber': '25',
#      'userCount': 1231,
#      'id': 825133,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 785203200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'خافيير جالان جيل'},
#       'shortNameTranslation': {'ar': 'خ. ج. جيل'}}},
#     'shirtNumber': 25,
#     'jerseyNumber': '25',
#     'position': 'D',
#     'substitute': False,
#     'statistics': {'totalPass': 32,
#      'accuratePass': 27,
#      'totalLongBalls': 2,
#      'totalCross': 4,
#      'accurateCross': 1,
#      'aerialWon': 1,
#      'duelLost': 5,
#      'duelWon': 10,
#      'challengeLost': 2,
#      'dispossessed': 1,
#      'totalContest': 3,
#      'wonContest': 1,
#      'totalClearance': 2,
#      'interceptionWon': 1,
#      'totalTackle': 7,
#      'wasFouled': 1,
#      'minutesPlayed': 90,
#      'touches': 62,
#      'rating': 7.1,
#      'possessionLostCtrl': 12,
#      'ratingVersions': {'original': 7.1, 'alternative': 7.3},
#      'expectedAssists': 0.0501653}},
#    {'player': {'name': 'Sheraldo Becker',
#      'slug': 'sheraldo-becker',
#      'shortName': 'S. Becker',
#      'position': 'F',
#      'jerseyNumber': '11',
#      'userCount': 1613,
#      'id': 352544,
#      'country': {'alpha2': 'SR', 'name': 'Suriname'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 792288000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'شيرالدو بيكر'},
#       'shortNameTranslation': {'ar': 'ش. بيكر'}}},
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 12,
#      'accuratePass': 8,
#      'totalCross': 2,
#      'aerialLost': 2,
#      'duelLost': 4,
#      'dispossessed': 1,
#      'shotOffTarget': 1,
#      'fouls': 1,
#      'minutesPlayed': 52,
#      'touches': 19,
#      'rating': 6.5,
#      'possessionLostCtrl': 9,
#      'expectedGoals': 0.0454,
#      'ratingVersions': {'original': 6.5, 'alternative': 6.4},
#      'expectedAssists': 0.00660582}},
#    {'player': {'name': 'Beñat Turrientes',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'benat-turrientes',
#      'shortName': 'B. Turrientes',
#      'position': 'M',
#      'jerseyNumber': '22',
#      'userCount': 364,
#      'id': 980410,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1012435200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بينيات تورينتيس'},
#       'shortNameTranslation': {'ar': 'ب. تورينتيس'}}},
#     'shirtNumber': 22,
#     'jerseyNumber': '22',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 20,
#      'accuratePass': 19,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 3,
#      'totalCross': 1,
#      'aerialLost': 1,
#      'aerialWon': 1,
#      'duelLost': 5,
#      'duelWon': 3,
#      'challengeLost': 1,
#      'totalContest': 1,
#      'wonContest': 1,
#      'totalClearance': 1,
#      'totalTackle': 1,
#      'fouls': 3,
#      'minutesPlayed': 52,
#      'touches': 27,
#      'rating': 6.7,
#      'possessionLostCtrl': 4,
#      'keyPass': 1,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6},
#      'expectedAssists': 0.0133604}},
#    {'player': {'name': 'Martín Zubimendi',
#      'slug': 'martin-zubimendi',
#      'shortName': 'M. Zubimendi',
#      'position': 'M',
#      'jerseyNumber': '4',
#      'userCount': 2502,
#      'id': 966837,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 917913600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'مارتن زوبيمندي'},
#       'shortNameTranslation': {'ar': 'م. زوبيمندي'}}},
#     'shirtNumber': 4,
#     'jerseyNumber': '4',
#     'position': 'M',
#     'substitute': False,
#     'statistics': {'totalPass': 54,
#      'accuratePass': 53,
#      'totalLongBalls': 2,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialLost': 2,
#      'aerialWon': 1,
#      'duelLost': 6,
#      'duelWon': 1,
#      'dispossessed': 1,
#      'totalClearance': 2,
#      'interceptionWon': 2,
#      'fouls': 3,
#      'minutesPlayed': 90,
#      'touches': 66,
#      'rating': 6.7,
#      'possessionLostCtrl': 5,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6},
#      'expectedAssists': 0.0102803}},
#    {'player': {'name': 'Mikel Oyarzabal',
#      'slug': 'mikel-oyarzabal',
#      'shortName': 'M. Oyarzabal',
#      'position': 'F',
#      'jerseyNumber': '10',
#      'userCount': 4500,
#      'id': 823622,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 861580800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أويارزابال, ميكيل'},
#       'shortNameTranslation': {'ar': 'م. أويارزابال'}}},
#     'shirtNumber': 10,
#     'jerseyNumber': '10',
#     'position': 'M',
#     'substitute': False,
#     'captain': True,
#     'statistics': {'totalPass': 31,
#      'accuratePass': 25,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 3,
#      'totalCross': 1,
#      'aerialLost': 1,
#      'aerialWon': 2,
#      'duelLost': 7,
#      'duelWon': 5,
#      'challengeLost': 1,
#      'dispossessed': 3,
#      'totalContest': 2,
#      'wonContest': 2,
#      'blockedScoringAttempt': 1,
#      'outfielderBlock': 1,
#      'totalTackle': 1,
#      'fouls': 2,
#      'totalOffside': 1,
#      'minutesPlayed': 89,
#      'touches': 45,
#      'rating': 6.9,
#      'possessionLostCtrl': 12,
#      'expectedGoals': 0.0332,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.7},
#      'expectedAssists': 0.0832798}},
#    {'player': {'name': 'Brais Méndez',
#      'slug': 'brais-mendez',
#      'shortName': 'B. Méndez',
#      'position': 'M',
#      'jerseyNumber': '23',
#      'userCount': 1967,
#      'id': 845385,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 852595200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'},
#       'shortNameTranslation': {'ar': 'ب. منديز'}}},
#     'shirtNumber': 23,
#     'jerseyNumber': '23',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'totalPass': 33,
#      'accuratePass': 25,
#      'totalLongBalls': 3,
#      'accurateLongBalls': 1,
#      'totalCross': 6,
#      'accurateCross': 2,
#      'duelLost': 7,
#      'duelWon': 3,
#      'challengeLost': 1,
#      'dispossessed': 1,
#      'totalContest': 2,
#      'onTargetScoringAttempt': 1,
#      'blockedScoringAttempt': 1,
#      'totalClearance': 1,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'wasFouled': 2,
#      'fouls': 3,
#      'minutesPlayed': 87,
#      'touches': 50,
#      'rating': 7.1,
#      'possessionLostCtrl': 16,
#      'expectedGoals': 0.1898,
#      'keyPass': 2,
#      'ratingVersions': {'original': 7.1, 'alternative': 7.1},
#      'expectedAssists': 0.29178}},
#    {'player': {'name': 'André Silva',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'andre-silva',
#      'shortName': 'A. Silva',
#      'position': 'F',
#      'jerseyNumber': '21',
#      'userCount': 6798,
#      'id': 190159,
#      'country': {'alpha2': 'PT', 'name': 'Portugal'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 815616000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'},
#       'shortNameTranslation': {'ar': 'أ. سيلفا'}}},
#     'shirtNumber': 21,
#     'jerseyNumber': '21',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'totalPass': 20,
#      'accuratePass': 17,
#      'aerialLost': 3,
#      'aerialWon': 3,
#      'duelLost': 12,
#      'duelWon': 6,
#      'challengeLost': 1,
#      'dispossessed': 5,
#      'totalContest': 1,
#      'shotOffTarget': 2,
#      'onTargetScoringAttempt': 1,
#      'totalClearance': 1,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'wasFouled': 2,
#      'fouls': 3,
#      'minutesPlayed': 87,
#      'touches': 43,
#      'rating': 6.8,
#      'possessionLostCtrl': 13,
#      'expectedGoals': 0.11,
#      'keyPass': 1,
#      'ratingVersions': {'original': 6.8, 'alternative': 6.7},
#      'expectedAssists': 0.0350007}},
#    {'player': {'name': 'Jon Aramburu',
#      'firstName': 'Jon Aramburu',
#      'lastName': '',
#      'slug': 'jon-aramburu',
#      'shortName': 'J. Aramburu',
#      'position': 'M',
#      'jerseyNumber': '39',
#      'userCount': 343,
#      'id': 1116388,
#      'country': {'alpha2': 'VE', 'name': 'Venezuela'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1027382400},
#     'shirtNumber': 39,
#     'jerseyNumber': '39',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {'totalPass': 33,
#      'accuratePass': 28,
#      'totalLongBalls': 4,
#      'accurateLongBalls': 1,
#      'totalCross': 1,
#      'aerialWon': 1,
#      'duelLost': 3,
#      'duelWon': 6,
#      'challengeLost': 1,
#      'dispossessed': 1,
#      'totalContest': 1,
#      'shotOffTarget': 1,
#      'totalClearance': 2,
#      'interceptionWon': 1,
#      'totalTackle': 4,
#      'wasFouled': 1,
#      'minutesPlayed': 87,
#      'touches': 57,
#      'rating': 6.9,
#      'possessionLostCtrl': 13,
#      'expectedGoals': 0.0174,
#      'ratingVersions': {'original': 6.9, 'alternative': 6.8},
#      'expectedAssists': 0.0107032}},
#    {'player': {'name': 'Mikel Merino',
#      'slug': 'mikel-merino',
#      'shortName': 'M. Merino',
#      'position': 'M',
#      'jerseyNumber': '8',
#      'userCount': 2036,
#      'id': 592010,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 835401600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ميرينو, ميكيل'},
#       'shortNameTranslation': {'ar': 'م. ميرينو'}}},
#     'shirtNumber': 8,
#     'jerseyNumber': '8',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'totalPass': 25,
#      'accuratePass': 21,
#      'aerialLost': 3,
#      'duelLost': 8,
#      'duelWon': 1,
#      'challengeLost': 2,
#      'dispossessed': 1,
#      'totalContest': 1,
#      'totalClearance': 1,
#      'outfielderBlock': 2,
#      'interceptionWon': 1,
#      'totalTackle': 1,
#      'fouls': 1,
#      'minutesPlayed': 38,
#      'touches': 36,
#      'rating': 6.7,
#      'possessionLostCtrl': 7,
#      'keyPass': 2,
#      'ratingVersions': {'original': 6.7, 'alternative': 6.6},
#      'expectedAssists': 0.0118951}},
#    {'player': {'name': 'Ander Barrenetxea',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'ander-barrenetxea',
#      'shortName': 'A. Barrenetxea',
#      'position': 'F',
#      'jerseyNumber': '7',
#      'userCount': 1229,
#      'id': 966862,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1009411200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بارنيتكسيا, أندر'},
#       'shortNameTranslation': {'ar': 'أ. بارنيتكسيا'}}},
#     'shirtNumber': 7,
#     'jerseyNumber': '7',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'totalPass': 9,
#      'accuratePass': 4,
#      'totalLongBalls': 1,
#      'totalCross': 4,
#      'accurateCross': 1,
#      'aerialWon': 2,
#      'duelLost': 3,
#      'duelWon': 11,
#      'dispossessed': 1,
#      'totalContest': 2,
#      'wonContest': 1,
#      'blockedScoringAttempt': 1,
#      'outfielderBlock': 1,
#      'totalTackle': 6,
#      'wasFouled': 2,
#      'fouls': 1,
#      'minutesPlayed': 38,
#      'touches': 33,
#      'rating': 7.4,
#      'possessionLostCtrl': 13,
#      'expectedGoals': 0.03,
#      'ratingVersions': {'original': 7.4, 'alternative': 7.1},
#      'expectedAssists': 0.00573558}},
#    {'player': {'name': 'Jon Ander Olasagasti',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'jon-ander-olasagasti',
#      'shortName': 'J. A. Olasagasti',
#      'position': 'M',
#      'jerseyNumber': '16',
#      'userCount': 93,
#      'id': 1010383,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 966384000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جون أندر أولاساغاستي'},
#       'shortNameTranslation': {'ar': 'ج. أ. أولاساغاستي'}}},
#     'shirtNumber': 16,
#     'jerseyNumber': '16',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {'minutesPlayed': 10,
#      'rating': 6.5,
#      'ratingVersions': {'original': 6.5, 'alternative': 6.5}}},
#    {'player': {'name': 'Umar Sadiq',
#      'slug': 'umar-sadiq',
#      'shortName': 'U. Sadiq',
#      'position': 'F',
#      'jerseyNumber': '19',
#      'userCount': 2317,
#      'id': 754710,
#      'country': {'alpha2': 'NG', 'name': 'Nigeria'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 854841600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'عمر صادق'},
#       'shortNameTranslation': {'ar': 'ع. صادق'}}},
#     'shirtNumber': 19,
#     'jerseyNumber': '19',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'totalPass': 1,
#      'accuratePass': 1,
#      'aerialLost': 1,
#      'duelLost': 1,
#      'totalClearance': 1,
#      'totalOffside': 1,
#      'minutesPlayed': 10,
#      'touches': 2,
#      'rating': 6.5,
#      'ratingVersions': {'original': 6.5, 'alternative': 6.5}}},
#    {'player': {'name': 'Unai Marrero',
#      'firstName': 'Unai Marrero',
#      'lastName': '',
#      'slug': 'unai-marrero',
#      'shortName': 'U. Marrero',
#      'position': 'G',
#      'jerseyNumber': '13',
#      'userCount': 92,
#      'id': 1094782,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1002585600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ماريرو ، أوناي'},
#       'shortNameTranslation': {'ar': 'م. ، أوناي'}}},
#     'shirtNumber': 13,
#     'jerseyNumber': '13',
#     'position': 'G',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Robin Le Normand',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'robin-le-normand',
#      'shortName': 'R. Le Normand',
#      'position': 'D',
#      'jerseyNumber': '24',
#      'userCount': 1304,
#      'id': 787751,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 847670400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'لو نورماند, روبين'},
#       'shortNameTranslation': {'ar': 'ر. ل. نورماند'}}},
#     'shirtNumber': 24,
#     'jerseyNumber': '24',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Jon Martin Vicente',
#      'firstName': 'Jon Martín',
#      'slug': 'vicente-jon-martin',
#      'shortName': 'J. Martín',
#      'position': 'D',
#      'jerseyNumber': '36',
#      'userCount': 136,
#      'id': 1466116,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1145750400},
#     'shirtNumber': 36,
#     'jerseyNumber': '36',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Iñaki Rupérez Urtasun',
#      'slug': 'inaki-ruperez-urtasun',
#      'shortName': 'I. R. Urtasun',
#      'position': 'D',
#      'jerseyNumber': '41',
#      'userCount': 7,
#      'id': 1526573,
#      'country': {},
#      'marketValueCurrency': 'EUR'},
#     'shirtNumber': 41,
#     'jerseyNumber': '41',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Urko González',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'urko-gonzalez',
#      'shortName': 'U. González',
#      'position': 'D',
#      'jerseyNumber': '15',
#      'userCount': 79,
#      'id': 1064009,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 985046400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أوركو جونزاليس'},
#       'shortNameTranslation': {'ar': 'أ. جونزاليس'}}},
#     'shirtNumber': 15,
#     'jerseyNumber': '15',
#     'position': 'D',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Jon Magunazelaia',
#      'firstName': 'Jon Magunacelaya',
#      'lastName': '',
#      'slug': 'jon-magunazelaia',
#      'shortName': 'J. Magunazelaia',
#      'position': 'M',
#      'jerseyNumber': '28',
#      'userCount': 37,
#      'id': 1134396,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 994982400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ماجوناسيلايا ، جون'},
#       'shortNameTranslation': {'ar': 'م. ، جون'}}},
#     'shirtNumber': 28,
#     'jerseyNumber': '28',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}},
#    {'player': {'name': 'Arsen Zakharyan',
#      'firstName': 'Arsen Zakharyan',
#      'slug': 'arsen-zakharyan',
#      'shortName': 'A. Zakharyan',
#      'position': 'M',
#      'jerseyNumber': '12',
#      'userCount': 3672,
#      'id': 1066045,
#      'country': {'alpha2': 'RU', 'name': 'Russia'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1053907200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أرسين زاخاريان'},
#       'shortNameTranslation': {'ar': 'أ. زاخاريان'}}},
#     'shirtNumber': 12,
#     'jerseyNumber': '12',
#     'position': 'M',
#     'substitute': True,
#     'statistics': {}}],
#   'supportStaff': [],
#   'formation': '4-4-1-1',
#   'playerColor': {'primary': '2a3a57',
#    'number': 'ffffff',
#    'outline': '2a3a57',
#    'fancyNumber': 'ffffff'},
#   'goalkeeperColor': {'primary': '25ff00',
#    'number': 'ffffff',
#    'outline': '25ff00',
#    'fancyNumber': '222226'},
#   'missingPlayers': [{'player': {'name': 'Martín Merquelanz',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'martin-merquelanz',
#      'shortName': 'M. Merquelanz',
#      'position': 'F',
#      'jerseyNumber': '99',
#      'userCount': 181,
#      'id': 353252,
#      'country': {'alpha2': 'ES', 'name': 'Spain'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 802915200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ميركيلانز, مارتين'},
#       'shortNameTranslation': {'ar': 'م. ميركيلانز'}}},
#     'type': 'missing',
#     'reason': 1},
#    {'player': {'name': 'Hamari Traoré',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'hamari-traore',
#      'shortName': 'H. Traoré',
#      'position': 'D',
#      'jerseyNumber': '18',
#      'userCount': 2513,
#      'id': 362014,
#      'country': {'alpha2': 'ML', 'name': 'Mali'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 696470400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'هاماري تراوري'},
#       'shortNameTranslation': {'ar': 'ه. تراوري'}}},
#     'type': 'missing',
#     'reason': 0},
#    {'player': {'name': 'Takefusa Kubo',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'kubo-takefusa',
#      'shortName': 'T. Kubo',
#      'position': 'M',
#      'jerseyNumber': '14',
#      'userCount': 16838,
#      'id': 880218,
#      'country': {'alpha2': 'JP', 'name': 'Japan'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 991612800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'تاكيفوسا كوبو'},
#       'shortNameTranslation': {'ar': 'ت. كوبو'}}},
#     'type': 'missing',
#     'reason': 0}]}}

# %%
for x in pstats:
    print(x)
    if x == 'home':
        for y in pstats[x]['players']:
            y['type'] = 'home'
            print(y)
    elif x == 'away':
        for y in pstats[x]['players']:
            y['type'] = 'away'
            print(y)
# Out:
# confirmed
# home
# {'player': {'name': 'Paulo Gazzaniga', 'slug': 'paulo-gazzaniga', 'shortName': 'P. Gazzaniga', 'position': 'G', 'jerseyNumber': '13', 'userCount': 1680, 'id': 164343, 'country': {'alpha2': 'AR', 'name': 'Argentina'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 694310400, 'fieldTranslations': {'nameTranslation': {'ar': 'غازانيجا, باولو'}, 'shortNameTranslation': {'ar': 'ب. غازانيجا'}}}, 'shirtNumber': 13, 'jerseyNumber': '13', 'position': 'G', 'substitute': False, 'statistics': {'totalPass': 45, 'accuratePass': 26, 'totalLongBalls': 27, 'accurateLongBalls': 9, 'savedShotsFromInsideTheBox': 1, 'saves': 2, 'minutesPlayed': 90, 'touches': 51, 'rating': 7, 'possessionLostCtrl': 21, 'ratingVersions': {'original': 7, 'alternative': 7.3}, 'goalsPrevented': 0.1831}, 'type': 'home'}
# {'player': {'name': 'Yan Couto', 'firstName': '', 'lastName': '', 'slug': 'couto-yan', 'shortName': 'Y. Couto', 'position': 'M', 'jerseyNumber': '20', 'userCount': 3412, 'id': 1002813, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1023062400, 'fieldTranslations': {'nameTranslation': {'ar': 'يان كوتو'}, 'shortNameTranslation': {'ar': 'ي. كوتو'}}}, 'shirtNumber': 20, 'jerseyNumber': '20', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 52, 'accuratePass': 44, 'totalLongBalls': 3, 'accurateLongBalls': 3, 'totalCross': 1, 'accurateCross': 1, 'aerialLost': 1, 'duelLost': 11, 'duelWon': 6, 'dispossessed': 4, 'totalContest': 8, 'wonContest': 3, 'bigChanceCreated': 1, 'totalTackle': 1, 'wasFouled': 2, 'fouls': 1, 'minutesPlayed': 90, 'touches': 83, 'rating': 6.8, 'possessionLostCtrl': 20, 'keyPass': 2, 'ratingVersions': {'original': 6.8, 'alternative': 6.7}, 'expectedAssists': 0.195063}, 'type': 'home'}
# {'player': {'name': 'Eric García', 'slug': 'eric-garcia', 'shortName': 'E. García', 'position': 'D', 'jerseyNumber': '25', 'userCount': 8185, 'id': 876214, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 978998400, 'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, اريك'}, 'shortNameTranslation': {'ar': 'ا. جارسيا'}}}, 'shirtNumber': 25, 'jerseyNumber': '25', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 52, 'accuratePass': 47, 'totalLongBalls': 4, 'accurateLongBalls': 3, 'aerialLost': 1, 'aerialWon': 2, 'duelLost': 2, 'duelWon': 6, 'totalClearance': 5, 'interceptionWon': 1, 'totalTackle': 3, 'wasFouled': 1, 'fouls': 1, 'minutesPlayed': 90, 'touches': 63, 'rating': 7.5, 'possessionLostCtrl': 5, 'ratingVersions': {'original': 7.5, 'alternative': 7.6}, 'expectedAssists': 0.137272}, 'type': 'home'}
# {'player': {'name': 'Daley Blind', 'firstName': '', 'lastName': '', 'slug': 'daley-blind', 'shortName': 'D. Blind', 'position': 'D', 'jerseyNumber': '17', 'userCount': 3766, 'id': 44864, 'country': {'alpha2': 'NL', 'name': 'Netherlands'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 636940800, 'fieldTranslations': {'nameTranslation': {'ar': 'دالي بلايند'}, 'shortNameTranslation': {'ar': 'د. بلايند'}}}, 'shirtNumber': 17, 'jerseyNumber': '17', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 60, 'accuratePass': 54, 'totalLongBalls': 2, 'totalCross': 1, 'aerialLost': 2, 'aerialWon': 4, 'duelLost': 3, 'duelWon': 4, 'challengeLost': 1, 'shotOffTarget': 1, 'blockedScoringAttempt': 1, 'totalClearance': 4, 'minutesPlayed': 90, 'touches': 73, 'rating': 6.9, 'possessionLostCtrl': 9, 'expectedGoals': 0.0709, 'ratingVersions': {'original': 6.9, 'alternative': 6.9}, 'expectedAssists': 0.00781402}, 'type': 'home'}
# {'player': {'name': 'Miguel Gutiérrez', 'slug': 'miguel-gutierrez', 'shortName': 'M. Gutiérrez', 'position': 'D', 'jerseyNumber': '3', 'userCount': 2755, 'id': 908716, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 996192000, 'fieldTranslations': {'nameTranslation': {'ar': 'جوتيريز ، ميغيل'}, 'shortNameTranslation': {'ar': 'ج. ، ميغيل'}}}, 'shirtNumber': 3, 'jerseyNumber': '3', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 35, 'accuratePass': 32, 'totalLongBalls': 1, 'accurateLongBalls': 1, 'totalCross': 1, 'aerialLost': 1, 'aerialWon': 1, 'duelLost': 2, 'duelWon': 2, 'dispossessed': 1, 'totalContest': 1, 'wonContest': 1, 'blockedScoringAttempt': 1, 'outfielderBlock': 2, 'minutesPlayed': 90, 'touches': 51, 'rating': 7.2, 'possessionLostCtrl': 6, 'expectedGoals': 0.0556, 'keyPass': 1, 'ratingVersions': {'original': 7.2, 'alternative': 7.1}, 'expectedAssists': 0.0363362}, 'type': 'home'}
# {'player': {'name': 'Yangel Herrera', 'slug': 'yangel-herrera', 'shortName': 'Y. Herrera', 'position': 'M', 'jerseyNumber': '21', 'userCount': 2365, 'id': 839585, 'country': {'alpha2': 'VE', 'name': 'Venezuela'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 884131200, 'fieldTranslations': {'nameTranslation': {'ar': 'يانخيل هيريرا'}, 'shortNameTranslation': {'ar': 'ي. هيريرا'}}}, 'shirtNumber': 21, 'jerseyNumber': '21', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 26, 'accuratePass': 22, 'totalLongBalls': 1, 'accurateLongBalls': 1, 'totalCross': 1, 'aerialLost': 4, 'aerialWon': 4, 'duelLost': 11, 'duelWon': 15, 'challengeLost': 3, 'dispossessed': 2, 'totalContest': 1, 'wonContest': 1, 'onTargetScoringAttempt': 1, 'blockedScoringAttempt': 2, 'totalClearance': 1, 'interceptionWon': 1, 'totalTackle': 4, 'wasFouled': 6, 'fouls': 2, 'minutesPlayed': 90, 'touches': 53, 'rating': 7.4, 'possessionLostCtrl': 9, 'expectedGoals': 0.1257, 'ratingVersions': {'original': 7.4, 'alternative': 7.1}, 'expectedAssists': 0.00849824}, 'type': 'home'}
# {'player': {'name': 'Aleix García', 'firstName': '', 'lastName': '', 'slug': 'aleix-garcia', 'shortName': 'A. García', 'position': 'M', 'jerseyNumber': '14', 'userCount': 2900, 'id': 796047, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 867456000, 'fieldTranslations': {'nameTranslation': {'ar': 'جارسيا, أليكس'}, 'shortNameTranslation': {'ar': 'أ. جارسيا'}}}, 'shirtNumber': 14, 'jerseyNumber': '14', 'position': 'M', 'substitute': False, 'captain': True, 'statistics': {'totalPass': 31, 'accuratePass': 28, 'totalLongBalls': 1, 'accurateLongBalls': 1, 'totalCross': 1, 'duelLost': 1, 'duelWon': 5, 'onTargetScoringAttempt': 1, 'blockedScoringAttempt': 1, 'totalClearance': 1, 'totalTackle': 3, 'errorLeadToAShot': 1, 'wasFouled': 2, 'fouls': 1, 'minutesPlayed': 80, 'touches': 44, 'rating': 7, 'possessionLostCtrl': 5, 'expectedGoals': 0.1655, 'keyPass': 1, 'ratingVersions': {'original': 7, 'alternative': 7}, 'expectedAssists': 0.0613259}, 'type': 'home'}
# {'player': {'name': 'Viktor Tsygankov', 'firstName': '', 'lastName': '', 'slug': 'viktor-tsygankov', 'shortName': 'V. Tsygankov', 'position': 'M', 'jerseyNumber': '8', 'userCount': 4344, 'id': 319735, 'country': {'alpha2': 'UA', 'name': 'Ukraine'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 879552000, 'fieldTranslations': {'nameTranslation': {'ar': 'فيكتور تسيغانكوف'}, 'shortNameTranslation': {'ar': 'ف. تسيغانكوف'}}}, 'shirtNumber': 8, 'jerseyNumber': '8', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 23, 'accuratePass': 16, 'totalLongBalls': 1, 'totalCross': 2, 'aerialLost': 1, 'aerialWon': 1, 'duelLost': 6, 'duelWon': 4, 'challengeLost': 1, 'dispossessed': 3, 'onTargetScoringAttempt': 1, 'totalClearance': 5, 'totalTackle': 3, 'fouls': 1, 'minutesPlayed': 80, 'touches': 40, 'rating': 6.9, 'possessionLostCtrl': 12, 'expectedGoals': 0.0782, 'ratingVersions': {'original': 6.9, 'alternative': 6.6}, 'expectedAssists': 0.0195499}, 'type': 'home'}
# {'player': {'name': 'Iván Martín', 'slug': 'ivan-martin', 'shortName': 'I. Martín', 'position': 'M', 'jerseyNumber': '23', 'userCount': 781, 'id': 973699, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 918950400, 'fieldTranslations': {'nameTranslation': {'ar': 'مارتن, إيفان'}, 'shortNameTranslation': {'ar': 'إ. مارتن'}}}, 'shirtNumber': 23, 'jerseyNumber': '23', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 27, 'accuratePass': 23, 'totalLongBalls': 1, 'accurateLongBalls': 1, 'aerialLost': 1, 'duelLost': 1, 'duelWon': 4, 'totalTackle': 1, 'wasFouled': 3, 'minutesPlayed': 70, 'touches': 32, 'rating': 6.8, 'possessionLostCtrl': 4, 'ratingVersions': {'original': 6.8, 'alternative': 6.8}, 'expectedAssists': 0.0124752}, 'type': 'home'}
# {'player': {'name': 'Sávio', 'firstName': 'Sávio', 'lastName': '', 'slug': 'savio', 'shortName': 'Sávio', 'position': 'M', 'jerseyNumber': '16', 'userCount': 5695, 'id': 1046795, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1081555200, 'fieldTranslations': {'nameTranslation': {'ar': 'سافيو'}, 'shortNameTranslation': {'ar': 'سافيو'}}}, 'shirtNumber': 16, 'jerseyNumber': '16', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 23, 'accuratePass': 19, 'totalLongBalls': 2, 'accurateLongBalls': 2, 'totalCross': 3, 'aerialLost': 2, 'aerialWon': 1, 'duelLost': 12, 'duelWon': 11, 'dispossessed': 3, 'totalContest': 7, 'wonContest': 2, 'shotOffTarget': 1, 'totalClearance': 1, 'totalTackle': 5, 'wasFouled': 3, 'fouls': 2, 'totalOffside': 1, 'minutesPlayed': 90, 'touches': 52, 'rating': 7.1, 'possessionLostCtrl': 18, 'expectedGoals': 0.0342, 'keyPass': 3, 'ratingVersions': {'original': 7.1, 'alternative': 7}, 'expectedAssists': 0.157888}, 'type': 'home'}
# {'player': {'name': 'Portu', 'firstName': '', 'lastName': '', 'slug': 'portu', 'shortName': 'Portu', 'position': 'M', 'jerseyNumber': '24', 'userCount': 898, 'id': 218616, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 706406400, 'fieldTranslations': {'nameTranslation': {'ar': 'بورتو'}, 'shortNameTranslation': {'ar': 'بورتو'}}}, 'shirtNumber': 24, 'jerseyNumber': '24', 'position': 'F', 'substitute': False, 'statistics': {'totalPass': 6, 'accuratePass': 6, 'aerialLost': 1, 'duelLost': 1, 'duelWon': 1, 'totalTackle': 1, 'totalOffside': 3, 'minutesPlayed': 70, 'touches': 11, 'rating': 6.6, 'possessionLostCtrl': 1, 'ratingVersions': {'original': 6.6, 'alternative': 6.5}, 'expectedAssists': 0.0184663}, 'type': 'home'}
# {'player': {'name': 'Pablo Torre', 'firstName': '', 'lastName': '', 'slug': 'pablo-torre', 'shortName': 'P. Torre', 'position': 'M', 'jerseyNumber': '18', 'userCount': 6990, 'id': 1082981, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1049328000, 'fieldTranslations': {'nameTranslation': {'ar': 'توري كارال ، بابلو'}, 'shortNameTranslation': {'ar': 'ت. ك. ، بابلو'}}}, 'shirtNumber': 18, 'jerseyNumber': '18', 'position': 'M', 'substitute': True, 'statistics': {'totalPass': 5, 'accuratePass': 5, 'duelWon': 1, 'totalTackle': 1, 'minutesPlayed': 20, 'touches': 7, 'rating': 6.6, 'possessionLostCtrl': 1, 'ratingVersions': {'original': 6.6, 'alternative': 6.6}}, 'type': 'home'}
# {'player': {'name': 'Cristhian Stuani', 'slug': 'cristhian-stuani', 'shortName': 'C. Stuani', 'position': 'F', 'jerseyNumber': '7', 'userCount': 1991, 'id': 32048, 'country': {'alpha2': 'UY', 'name': 'Uruguay'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 529459200, 'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان ستواني'}, 'shortNameTranslation': {'ar': 'ك. ستواني'}}}, 'shirtNumber': 7, 'jerseyNumber': '7', 'position': 'F', 'substitute': True, 'statistics': {'totalPass': 4, 'accuratePass': 2, 'aerialLost': 1, 'duelLost': 1, 'totalClearance': 2, 'outfielderBlock': 1, 'minutesPlayed': 20, 'touches': 11, 'rating': 6.7, 'possessionLostCtrl': 4, 'ratingVersions': {'original': 6.7, 'alternative': 6.6}}, 'type': 'home'}
# {'player': {'name': 'Valery Fernández', 'slug': 'valery-fernandez', 'shortName': 'V. Fernández', 'position': 'D', 'jerseyNumber': '11', 'userCount': 360, 'id': 962378, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 943315200, 'fieldTranslations': {'nameTranslation': {'ar': 'فرنانديز ، فاليري'}, 'shortNameTranslation': {'ar': 'ف. ، فاليري'}}}, 'shirtNumber': 11, 'jerseyNumber': '11', 'position': 'D', 'substitute': True, 'statistics': {'totalPass': 3, 'accuratePass': 2, 'totalCross': 1, 'aerialWon': 1, 'duelWon': 3, 'bigChanceMissed': 1, 'shotOffTarget': 1, 'totalTackle': 1, 'wasFouled': 1, 'minutesPlayed': 10, 'touches': 8, 'rating': 6.7, 'possessionLostCtrl': 3, 'expectedGoals': 0.1904, 'ratingVersions': {'original': 6.7, 'alternative': 6.6}}, 'type': 'home'}
# {'player': {'name': 'Jhon Solís', 'firstName': 'Jhon Solis', 'slug': 'jhon-solis', 'shortName': 'J. Solís', 'position': 'M', 'jerseyNumber': '22', 'userCount': 793, 'id': 1106573, 'country': {'alpha2': 'CO', 'name': 'Colombia'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1096761600, 'fieldTranslations': {'nameTranslation': {'ar': 'Solis, Jhon Elmer'}, 'shortNameTranslation': {'ar': 'J. E. Solis'}}}, 'shirtNumber': 22, 'jerseyNumber': '22', 'position': 'M', 'substitute': True, 'statistics': {'totalPass': 11, 'accuratePass': 10, 'aerialLost': 1, 'aerialWon': 1, 'duelLost': 1, 'duelWon': 3, 'totalContest': 2, 'wonContest': 2, 'interceptionWon': 1, 'minutesPlayed': 10, 'touches': 14, 'rating': 6.9, 'possessionLostCtrl': 1, 'expectedGoals': 0.024, 'ratingVersions': {'original': 6.9, 'alternative': 6.9}, 'expectedAssists': 0.0104714}, 'type': 'home'}
# {'player': {'name': 'Toni Fuidias', 'slug': 'toni-fuidias', 'shortName': 'T. Fuidias', 'position': 'G', 'jerseyNumber': '26', 'userCount': 460, 'id': 991960, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 987292800, 'fieldTranslations': {'nameTranslation': {'ar': 'فيدياس ريبيرا ، طوني'}, 'shortNameTranslation': {'ar': 'ف. ر. ، طوني'}}}, 'shirtNumber': 26, 'jerseyNumber': '26', 'position': 'G', 'substitute': True, 'statistics': {}, 'type': 'home'}
# {'player': {'name': 'Arnau Martínez', 'firstName': 'Arnau Martinez', 'slug': 'arnau-martinez', 'shortName': 'A. Martínez', 'position': 'D', 'jerseyNumber': '4', 'userCount': 1471, 'id': 1084081, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1051228800, 'fieldTranslations': {'nameTranslation': {'ar': 'أرناو ، مارتينيز'}, 'shortNameTranslation': {'ar': 'أ. ، مارتينيز'}}}, 'shirtNumber': 4, 'jerseyNumber': '4', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'home'}
# {'player': {'name': 'Antal Yaakobishvili', 'slug': 'yaakobishvili-antal', 'shortName': 'A. Yaakobishvili', 'position': 'D', 'jerseyNumber': '35', 'userCount': 740, 'id': 1471513, 'country': {'alpha2': 'HU', 'name': 'Hungary'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1089590400}, 'shirtNumber': 35, 'jerseyNumber': '35', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'home'}
# {'player': {'name': 'Juanpe', 'slug': 'juanpe', 'shortName': 'Juanpe', 'position': 'D', 'jerseyNumber': '15', 'userCount': 212, 'id': 129861, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 672969600, 'fieldTranslations': {'nameTranslation': {'ar': 'خوانبي'}, 'shortNameTranslation': {'ar': 'خوانبي'}}}, 'shirtNumber': 15, 'jerseyNumber': '15', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'home'}
# {'player': {'name': 'Borja García', 'slug': 'borja-garcia', 'shortName': 'B. García', 'position': 'M', 'jerseyNumber': '10', 'userCount': 207, 'id': 129472, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 657504000, 'fieldTranslations': {'nameTranslation': {'ar': 'بورخا'}, 'shortNameTranslation': {'ar': 'بورخا'}}}, 'shirtNumber': 10, 'jerseyNumber': '10', 'position': 'M', 'substitute': True, 'statistics': {}, 'type': 'home'}
# {'player': {'name': 'Ricard Artero', 'firstName': 'Ricard Artero', 'lastName': '', 'slug': 'ricard-artero', 'shortName': 'R. Artero', 'position': 'M', 'jerseyNumber': '36', 'userCount': 38, 'id': 1134432, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1044403200}, 'shirtNumber': 36, 'jerseyNumber': '36', 'position': 'M', 'substitute': True, 'statistics': {}, 'type': 'home'}
# away
# {'player': {'name': 'Álex Remiro', 'slug': 'alex-remiro', 'shortName': 'Á. Remiro', 'position': 'G', 'jerseyNumber': '1', 'userCount': 941, 'id': 791773, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 796003200, 'fieldTranslations': {'nameTranslation': {'ar': 'ريميرو, أليكس'}, 'shortNameTranslation': {'ar': 'أ. ريميرو'}}}, 'shirtNumber': 1, 'jerseyNumber': '1', 'position': 'G', 'substitute': False, 'statistics': {'totalPass': 32, 'accuratePass': 28, 'totalLongBalls': 9, 'accurateLongBalls': 5, 'savedShotsFromInsideTheBox': 2, 'saves': 3, 'minutesPlayed': 90, 'touches': 37, 'rating': 7.3, 'possessionLostCtrl': 4, 'ratingVersions': {'original': 7.3, 'alternative': 7.4}, 'goalsPrevented': 0.4932}, 'type': 'away'}
# {'player': {'name': 'Álvaro Odriozola', 'firstName': '', 'lastName': '', 'slug': 'alvaro-odriozola', 'shortName': 'Á. Odriozola', 'position': 'D', 'jerseyNumber': '2', 'userCount': 3774, 'id': 353250, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 818899200, 'fieldTranslations': {'nameTranslation': {'ar': 'أودريوزولا, ألفارو'}, 'shortNameTranslation': {'ar': 'أ. أودريوزولا'}}}, 'shirtNumber': 2, 'jerseyNumber': '2', 'position': 'D', 'substitute': False, 'statistics': {'totalClearance': 1, 'minutesPlayed': 3, 'touches': 1}, 'type': 'away'}
# {'player': {'name': 'Igor Zubeldia', 'slug': 'igor-zubeldia', 'shortName': 'I. Zubeldia', 'position': 'D', 'jerseyNumber': '5', 'userCount': 658, 'id': 838159, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 859680000, 'fieldTranslations': {'nameTranslation': {'ar': 'زوبيلديا, إيجور'}, 'shortNameTranslation': {'ar': 'إ. زوبيلديا'}}}, 'shirtNumber': 5, 'jerseyNumber': '5', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 60, 'accuratePass': 50, 'totalLongBalls': 8, 'accurateLongBalls': 4, 'aerialLost': 2, 'aerialWon': 2, 'duelLost': 3, 'duelWon': 2, 'shotOffTarget': 1, 'totalClearance': 4, 'outfielderBlock': 1, 'fouls': 1, 'minutesPlayed': 90, 'touches': 66, 'rating': 7.3, 'possessionLostCtrl': 10, 'expectedGoals': 0.1078, 'keyPass': 2, 'ratingVersions': {'original': 7.3, 'alternative': 7.2}, 'expectedAssists': 0.0321423}, 'type': 'away'}
# {'player': {'name': 'Jon Pacheco', 'firstName': '', 'lastName': '', 'slug': 'jon-pacheco', 'shortName': 'J. Pacheco', 'position': 'D', 'jerseyNumber': '20', 'userCount': 238, 'id': 934383, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 978912000, 'fieldTranslations': {'nameTranslation': {'ar': 'جون باتشيكو'}, 'shortNameTranslation': {'ar': 'ج. باتشيكو'}}}, 'shirtNumber': 20, 'jerseyNumber': '20', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 65, 'accuratePass': 63, 'totalLongBalls': 8, 'accurateLongBalls': 6, 'aerialWon': 3, 'duelLost': 1, 'duelWon': 4, 'blockedScoringAttempt': 1, 'totalClearance': 2, 'interceptionWon': 1, 'totalTackle': 1, 'fouls': 1, 'minutesPlayed': 90, 'touches': 74, 'rating': 7.3, 'possessionLostCtrl': 5, 'expectedGoals': 0.0697, 'ratingVersions': {'original': 7.3, 'alternative': 7.2}, 'expectedAssists': 0.00821221}, 'type': 'away'}
# {'player': {'name': 'Javi Galán', 'slug': 'javi-galan', 'shortName': 'J. Galán', 'position': 'D', 'jerseyNumber': '25', 'userCount': 1231, 'id': 825133, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 785203200, 'fieldTranslations': {'nameTranslation': {'ar': 'خافيير جالان جيل'}, 'shortNameTranslation': {'ar': 'خ. ج. جيل'}}}, 'shirtNumber': 25, 'jerseyNumber': '25', 'position': 'D', 'substitute': False, 'statistics': {'totalPass': 32, 'accuratePass': 27, 'totalLongBalls': 2, 'totalCross': 4, 'accurateCross': 1, 'aerialWon': 1, 'duelLost': 5, 'duelWon': 10, 'challengeLost': 2, 'dispossessed': 1, 'totalContest': 3, 'wonContest': 1, 'totalClearance': 2, 'interceptionWon': 1, 'totalTackle': 7, 'wasFouled': 1, 'minutesPlayed': 90, 'touches': 62, 'rating': 7.1, 'possessionLostCtrl': 12, 'ratingVersions': {'original': 7.1, 'alternative': 7.3}, 'expectedAssists': 0.0501653}, 'type': 'away'}
# {'player': {'name': 'Sheraldo Becker', 'slug': 'sheraldo-becker', 'shortName': 'S. Becker', 'position': 'F', 'jerseyNumber': '11', 'userCount': 1613, 'id': 352544, 'country': {'alpha2': 'SR', 'name': 'Suriname'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 792288000, 'fieldTranslations': {'nameTranslation': {'ar': 'شيرالدو بيكر'}, 'shortNameTranslation': {'ar': 'ش. بيكر'}}}, 'shirtNumber': 11, 'jerseyNumber': '11', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 12, 'accuratePass': 8, 'totalCross': 2, 'aerialLost': 2, 'duelLost': 4, 'dispossessed': 1, 'shotOffTarget': 1, 'fouls': 1, 'minutesPlayed': 52, 'touches': 19, 'rating': 6.5, 'possessionLostCtrl': 9, 'expectedGoals': 0.0454, 'ratingVersions': {'original': 6.5, 'alternative': 6.4}, 'expectedAssists': 0.00660582}, 'type': 'away'}
# {'player': {'name': 'Beñat Turrientes', 'firstName': '', 'lastName': '', 'slug': 'benat-turrientes', 'shortName': 'B. Turrientes', 'position': 'M', 'jerseyNumber': '22', 'userCount': 364, 'id': 980410, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1012435200, 'fieldTranslations': {'nameTranslation': {'ar': 'بينيات تورينتيس'}, 'shortNameTranslation': {'ar': 'ب. تورينتيس'}}}, 'shirtNumber': 22, 'jerseyNumber': '22', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 20, 'accuratePass': 19, 'totalLongBalls': 3, 'accurateLongBalls': 3, 'totalCross': 1, 'aerialLost': 1, 'aerialWon': 1, 'duelLost': 5, 'duelWon': 3, 'challengeLost': 1, 'totalContest': 1, 'wonContest': 1, 'totalClearance': 1, 'totalTackle': 1, 'fouls': 3, 'minutesPlayed': 52, 'touches': 27, 'rating': 6.7, 'possessionLostCtrl': 4, 'keyPass': 1, 'ratingVersions': {'original': 6.7, 'alternative': 6.6}, 'expectedAssists': 0.0133604}, 'type': 'away'}
# {'player': {'name': 'Martín Zubimendi', 'slug': 'martin-zubimendi', 'shortName': 'M. Zubimendi', 'position': 'M', 'jerseyNumber': '4', 'userCount': 2502, 'id': 966837, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 917913600, 'fieldTranslations': {'nameTranslation': {'ar': 'مارتن زوبيمندي'}, 'shortNameTranslation': {'ar': 'م. زوبيمندي'}}}, 'shirtNumber': 4, 'jerseyNumber': '4', 'position': 'M', 'substitute': False, 'statistics': {'totalPass': 54, 'accuratePass': 53, 'totalLongBalls': 2, 'accurateLongBalls': 1, 'totalCross': 1, 'aerialLost': 2, 'aerialWon': 1, 'duelLost': 6, 'duelWon': 1, 'dispossessed': 1, 'totalClearance': 2, 'interceptionWon': 2, 'fouls': 3, 'minutesPlayed': 90, 'touches': 66, 'rating': 6.7, 'possessionLostCtrl': 5, 'ratingVersions': {'original': 6.7, 'alternative': 6.6}, 'expectedAssists': 0.0102803}, 'type': 'away'}
# {'player': {'name': 'Mikel Oyarzabal', 'slug': 'mikel-oyarzabal', 'shortName': 'M. Oyarzabal', 'position': 'F', 'jerseyNumber': '10', 'userCount': 4500, 'id': 823622, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 861580800, 'fieldTranslations': {'nameTranslation': {'ar': 'أويارزابال, ميكيل'}, 'shortNameTranslation': {'ar': 'م. أويارزابال'}}}, 'shirtNumber': 10, 'jerseyNumber': '10', 'position': 'M', 'substitute': False, 'captain': True, 'statistics': {'totalPass': 31, 'accuratePass': 25, 'totalLongBalls': 3, 'accurateLongBalls': 3, 'totalCross': 1, 'aerialLost': 1, 'aerialWon': 2, 'duelLost': 7, 'duelWon': 5, 'challengeLost': 1, 'dispossessed': 3, 'totalContest': 2, 'wonContest': 2, 'blockedScoringAttempt': 1, 'outfielderBlock': 1, 'totalTackle': 1, 'fouls': 2, 'totalOffside': 1, 'minutesPlayed': 89, 'touches': 45, 'rating': 6.9, 'possessionLostCtrl': 12, 'expectedGoals': 0.0332, 'ratingVersions': {'original': 6.9, 'alternative': 6.7}, 'expectedAssists': 0.0832798}, 'type': 'away'}
# {'player': {'name': 'Brais Méndez', 'slug': 'brais-mendez', 'shortName': 'B. Méndez', 'position': 'M', 'jerseyNumber': '23', 'userCount': 1967, 'id': 845385, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 852595200, 'fieldTranslations': {'nameTranslation': {'ar': 'منديز, برايس'}, 'shortNameTranslation': {'ar': 'ب. منديز'}}}, 'shirtNumber': 23, 'jerseyNumber': '23', 'position': 'F', 'substitute': False, 'statistics': {'totalPass': 33, 'accuratePass': 25, 'totalLongBalls': 3, 'accurateLongBalls': 1, 'totalCross': 6, 'accurateCross': 2, 'duelLost': 7, 'duelWon': 3, 'challengeLost': 1, 'dispossessed': 1, 'totalContest': 2, 'onTargetScoringAttempt': 1, 'blockedScoringAttempt': 1, 'totalClearance': 1, 'interceptionWon': 1, 'totalTackle': 1, 'wasFouled': 2, 'fouls': 3, 'minutesPlayed': 87, 'touches': 50, 'rating': 7.1, 'possessionLostCtrl': 16, 'expectedGoals': 0.1898, 'keyPass': 2, 'ratingVersions': {'original': 7.1, 'alternative': 7.1}, 'expectedAssists': 0.29178}, 'type': 'away'}
# {'player': {'name': 'André Silva', 'firstName': '', 'lastName': '', 'slug': 'andre-silva', 'shortName': 'A. Silva', 'position': 'F', 'jerseyNumber': '21', 'userCount': 6798, 'id': 190159, 'country': {'alpha2': 'PT', 'name': 'Portugal'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 815616000, 'fieldTranslations': {'nameTranslation': {'ar': 'أندريه سيلفا'}, 'shortNameTranslation': {'ar': 'أ. سيلفا'}}}, 'shirtNumber': 21, 'jerseyNumber': '21', 'position': 'F', 'substitute': False, 'statistics': {'totalPass': 20, 'accuratePass': 17, 'aerialLost': 3, 'aerialWon': 3, 'duelLost': 12, 'duelWon': 6, 'challengeLost': 1, 'dispossessed': 5, 'totalContest': 1, 'shotOffTarget': 2, 'onTargetScoringAttempt': 1, 'totalClearance': 1, 'interceptionWon': 1, 'totalTackle': 1, 'wasFouled': 2, 'fouls': 3, 'minutesPlayed': 87, 'touches': 43, 'rating': 6.8, 'possessionLostCtrl': 13, 'expectedGoals': 0.11, 'keyPass': 1, 'ratingVersions': {'original': 6.8, 'alternative': 6.7}, 'expectedAssists': 0.0350007}, 'type': 'away'}
# {'player': {'name': 'Jon Aramburu', 'firstName': 'Jon Aramburu', 'lastName': '', 'slug': 'jon-aramburu', 'shortName': 'J. Aramburu', 'position': 'M', 'jerseyNumber': '39', 'userCount': 343, 'id': 1116388, 'country': {'alpha2': 'VE', 'name': 'Venezuela'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1027382400}, 'shirtNumber': 39, 'jerseyNumber': '39', 'position': 'D', 'substitute': True, 'statistics': {'totalPass': 33, 'accuratePass': 28, 'totalLongBalls': 4, 'accurateLongBalls': 1, 'totalCross': 1, 'aerialWon': 1, 'duelLost': 3, 'duelWon': 6, 'challengeLost': 1, 'dispossessed': 1, 'totalContest': 1, 'shotOffTarget': 1, 'totalClearance': 2, 'interceptionWon': 1, 'totalTackle': 4, 'wasFouled': 1, 'minutesPlayed': 87, 'touches': 57, 'rating': 6.9, 'possessionLostCtrl': 13, 'expectedGoals': 0.0174, 'ratingVersions': {'original': 6.9, 'alternative': 6.8}, 'expectedAssists': 0.0107032}, 'type': 'away'}
# {'player': {'name': 'Mikel Merino', 'slug': 'mikel-merino', 'shortName': 'M. Merino', 'position': 'M', 'jerseyNumber': '8', 'userCount': 2036, 'id': 592010, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 835401600, 'fieldTranslations': {'nameTranslation': {'ar': 'ميرينو, ميكيل'}, 'shortNameTranslation': {'ar': 'م. ميرينو'}}}, 'shirtNumber': 8, 'jerseyNumber': '8', 'position': 'M', 'substitute': True, 'statistics': {'totalPass': 25, 'accuratePass': 21, 'aerialLost': 3, 'duelLost': 8, 'duelWon': 1, 'challengeLost': 2, 'dispossessed': 1, 'totalContest': 1, 'totalClearance': 1, 'outfielderBlock': 2, 'interceptionWon': 1, 'totalTackle': 1, 'fouls': 1, 'minutesPlayed': 38, 'touches': 36, 'rating': 6.7, 'possessionLostCtrl': 7, 'keyPass': 2, 'ratingVersions': {'original': 6.7, 'alternative': 6.6}, 'expectedAssists': 0.0118951}, 'type': 'away'}
# {'player': {'name': 'Ander Barrenetxea', 'firstName': '', 'lastName': '', 'slug': 'ander-barrenetxea', 'shortName': 'A. Barrenetxea', 'position': 'F', 'jerseyNumber': '7', 'userCount': 1229, 'id': 966862, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1009411200, 'fieldTranslations': {'nameTranslation': {'ar': 'بارنيتكسيا, أندر'}, 'shortNameTranslation': {'ar': 'أ. بارنيتكسيا'}}}, 'shirtNumber': 7, 'jerseyNumber': '7', 'position': 'F', 'substitute': True, 'statistics': {'totalPass': 9, 'accuratePass': 4, 'totalLongBalls': 1, 'totalCross': 4, 'accurateCross': 1, 'aerialWon': 2, 'duelLost': 3, 'duelWon': 11, 'dispossessed': 1, 'totalContest': 2, 'wonContest': 1, 'blockedScoringAttempt': 1, 'outfielderBlock': 1, 'totalTackle': 6, 'wasFouled': 2, 'fouls': 1, 'minutesPlayed': 38, 'touches': 33, 'rating': 7.4, 'possessionLostCtrl': 13, 'expectedGoals': 0.03, 'ratingVersions': {'original': 7.4, 'alternative': 7.1}, 'expectedAssists': 0.00573558}, 'type': 'away'}
# {'player': {'name': 'Jon Ander Olasagasti', 'firstName': '', 'lastName': '', 'slug': 'jon-ander-olasagasti', 'shortName': 'J. A. Olasagasti', 'position': 'M', 'jerseyNumber': '16', 'userCount': 93, 'id': 1010383, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 966384000, 'fieldTranslations': {'nameTranslation': {'ar': 'جون أندر أولاساغاستي'}, 'shortNameTranslation': {'ar': 'ج. أ. أولاساغاستي'}}}, 'shirtNumber': 16, 'jerseyNumber': '16', 'position': 'M', 'substitute': True, 'statistics': {'minutesPlayed': 10, 'rating': 6.5, 'ratingVersions': {'original': 6.5, 'alternative': 6.5}}, 'type': 'away'}
# {'player': {'name': 'Umar Sadiq', 'slug': 'umar-sadiq', 'shortName': 'U. Sadiq', 'position': 'F', 'jerseyNumber': '19', 'userCount': 2317, 'id': 754710, 'country': {'alpha2': 'NG', 'name': 'Nigeria'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 854841600, 'fieldTranslations': {'nameTranslation': {'ar': 'عمر صادق'}, 'shortNameTranslation': {'ar': 'ع. صادق'}}}, 'shirtNumber': 19, 'jerseyNumber': '19', 'position': 'F', 'substitute': True, 'statistics': {'totalPass': 1, 'accuratePass': 1, 'aerialLost': 1, 'duelLost': 1, 'totalClearance': 1, 'totalOffside': 1, 'minutesPlayed': 10, 'touches': 2, 'rating': 6.5, 'ratingVersions': {'original': 6.5, 'alternative': 6.5}}, 'type': 'away'}
# {'player': {'name': 'Unai Marrero', 'firstName': 'Unai Marrero', 'lastName': '', 'slug': 'unai-marrero', 'shortName': 'U. Marrero', 'position': 'G', 'jerseyNumber': '13', 'userCount': 92, 'id': 1094782, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1002585600, 'fieldTranslations': {'nameTranslation': {'ar': 'ماريرو ، أوناي'}, 'shortNameTranslation': {'ar': 'م. ، أوناي'}}}, 'shirtNumber': 13, 'jerseyNumber': '13', 'position': 'G', 'substitute': True, 'statistics': {}, 'type': 'away'}
# {'player': {'name': 'Robin Le Normand', 'firstName': '', 'lastName': '', 'slug': 'robin-le-normand', 'shortName': 'R. Le Normand', 'position': 'D', 'jerseyNumber': '24', 'userCount': 1304, 'id': 787751, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 847670400, 'fieldTranslations': {'nameTranslation': {'ar': 'لو نورماند, روبين'}, 'shortNameTranslation': {'ar': 'ر. ل. نورماند'}}}, 'shirtNumber': 24, 'jerseyNumber': '24', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'away'}
# {'player': {'name': 'Jon Martin Vicente', 'firstName': 'Jon Martín', 'slug': 'vicente-jon-martin', 'shortName': 'J. Martín', 'position': 'D', 'jerseyNumber': '36', 'userCount': 136, 'id': 1466116, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1145750400}, 'shirtNumber': 36, 'jerseyNumber': '36', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'away'}
# {'player': {'name': 'Iñaki Rupérez Urtasun', 'slug': 'inaki-ruperez-urtasun', 'shortName': 'I. R. Urtasun', 'position': 'D', 'jerseyNumber': '41', 'userCount': 7, 'id': 1526573, 'country': {}, 'marketValueCurrency': 'EUR'}, 'shirtNumber': 41, 'jerseyNumber': '41', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'away'}
# {'player': {'name': 'Urko González', 'firstName': '', 'lastName': '', 'slug': 'urko-gonzalez', 'shortName': 'U. González', 'position': 'D', 'jerseyNumber': '15', 'userCount': 79, 'id': 1064009, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 985046400, 'fieldTranslations': {'nameTranslation': {'ar': 'أوركو جونزاليس'}, 'shortNameTranslation': {'ar': 'أ. جونزاليس'}}}, 'shirtNumber': 15, 'jerseyNumber': '15', 'position': 'D', 'substitute': True, 'statistics': {}, 'type': 'away'}
# {'player': {'name': 'Jon Magunazelaia', 'firstName': 'Jon Magunacelaya', 'lastName': '', 'slug': 'jon-magunazelaia', 'shortName': 'J. Magunazelaia', 'position': 'M', 'jerseyNumber': '28', 'userCount': 37, 'id': 1134396, 'country': {'alpha2': 'ES', 'name': 'Spain'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 994982400, 'fieldTranslations': {'nameTranslation': {'ar': 'ماجوناسيلايا ، جون'}, 'shortNameTranslation': {'ar': 'م. ، جون'}}}, 'shirtNumber': 28, 'jerseyNumber': '28', 'position': 'M', 'substitute': True, 'statistics': {}, 'type': 'away'}
# {'player': {'name': 'Arsen Zakharyan', 'firstName': 'Arsen Zakharyan', 'slug': 'arsen-zakharyan', 'shortName': 'A. Zakharyan', 'position': 'M', 'jerseyNumber': '12', 'userCount': 3672, 'id': 1066045, 'country': {'alpha2': 'RU', 'name': 'Russia'}, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1053907200, 'fieldTranslations': {'nameTranslation': {'ar': 'أرسين زاخاريان'}, 'shortNameTranslation': {'ar': 'أ. زاخاريان'}}}, 'shirtNumber': 12, 'jerseyNumber': '12', 'position': 'M', 'substitute': True, 'statistics': {}, 'type': 'away'}

# %%
#merge home and away
allP=pstats['home']['players'] + pstats['away']['players']

# %%
#convert to dataframe
import pandas as pd
df= pd.DataFrame(allP)

# %%
df.head()
# Out:
#                                               player  shirtNumber  \
# 0  {'name': 'Paulo Gazzaniga', 'slug': 'paulo-gaz...           13
# 1  {'name': 'Yan Couto', 'firstName': '', 'lastNa...           20
# 2  {'name': 'Eric García', 'slug': 'eric-garcia',...           25
# 3  {'name': 'Daley Blind', 'firstName': '', 'last...           17
# 4  {'name': 'Miguel Gutiérrez', 'slug': 'miguel-g...            3
#
#   jerseyNumber position  substitute  \
# 0           13        G       False
# 1           20        D       False
# 2           25        D       False
# 3           17        D       False
# 4            3        D       False
#
#                                           statistics  type captain
# 0  {'totalPass': 45, 'accuratePass': 26, 'totalLo...  home     NaN
# 1  {'totalPass': 52, 'accuratePass': 44, 'totalLo...  home     NaN
# 2  {'totalPass': 52, 'accuratePass': 47, 'totalLo...  home     NaN
# 3  {'totalPass': 60, 'accuratePass': 54, 'totalLo...  home     NaN
# 4  {'totalPass': 35, 'accuratePass': 32, 'totalLo...  home     NaN

# %%
df[['name', 'position']] = df['player'].apply(lambda x: pd.Series({'name': x['name'], 'position': x['position']}) if isinstance(x, dict) else pd.Series({'name': None, 'position': None, 'jerseyNumber': None}))
df.drop('player', axis=1, inplace=True)
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
df.head()
# Out:
#                name  shirtNumber jerseyNumber position  substitute  \
# 0   Paulo Gazzaniga           13           13        G       False
# 1         Yan Couto           20           20        M       False
# 2       Eric García           25           25        D       False
# 3       Daley Blind           17           17        D       False
# 4  Miguel Gutiérrez            3            3        D       False
#
#                                           statistics  type captain
# 0  {'totalPass': 45, 'accuratePass': 26, 'totalLo...  home     NaN
# 1  {'totalPass': 52, 'accuratePass': 44, 'totalLo...  home     NaN
# 2  {'totalPass': 52, 'accuratePass': 47, 'totalLo...  home     NaN
# 3  {'totalPass': 60, 'accuratePass': 54, 'totalLo...  home     NaN
# 4  {'totalPass': 35, 'accuratePass': 32, 'totalLo...  home     NaN

# %%
df[['totalPass', 'accuratePass', 'totalLongBalls', 'accurateLongBalls', 'savedShotsFromInsideTheBox', 'saves', 'minutesPlayed', 'touches', 'rating', 'possessionLostCtrl', 'ratingVersions', 'goalsPrevented']] = df['statistics'].apply(lambda x: pd.Series({'totalPass': x.get('totalPass'), 'accuratePass': x.get('accuratePass'), 'totalLongBalls': x.get('totalLongBalls'), 'accurateLongBalls': x.get('accurateLongBalls'), 'savedShotsFromInsideTheBox': x.get('savedShotsFromInsideTheBox'), 'saves': x.get('saves'), 'minutesPlayed': x.get('minutesPlayed'), 'touches': x.get('touches'), 'rating': x.get('rating'), 'possessionLostCtrl': x.get('possessionLostCtrl'), 'ratingVersions': x.get('ratingVersions'), 'goalsPrevented': x.get('goalsPrevented')}) if isinstance(x, dict) else pd.Series({'name': None, 'position': None, 'jerseyNumber': None, 'savedShotsFromInsideTheBox': None, 'saves': None, 'minutesPlayed': None, 'touches': None, 'rating': None, 'possessionLostCtrl': None, 'ratingVersions': None, 'goalsPrevented': None}))  
df.drop('statistics', axis=1, inplace=True)

# %%
df.head()
# Out:
#                name  shirtNumber jerseyNumber position  substitute  type  \
# 0   Paulo Gazzaniga           13           13        G       False  home
# 1         Yan Couto           20           20        M       False  home
# 2       Eric García           25           25        D       False  home
# 3       Daley Blind           17           17        D       False  home
# 4  Miguel Gutiérrez            3            3        D       False  home
#
#   captain  totalPass  accuratePass  totalLongBalls  accurateLongBalls  \
# 0     NaN       45.0          26.0            27.0                9.0
# 1     NaN       52.0          44.0             3.0                3.0
# 2     NaN       52.0          47.0             4.0                3.0
# 3     NaN       60.0          54.0             2.0                NaN
# 4     NaN       35.0          32.0             1.0                1.0
#
#    savedShotsFromInsideTheBox  saves  minutesPlayed  touches  rating  \
# 0                         1.0    2.0           90.0     51.0     7.0
# 1                         NaN    NaN           90.0     83.0     6.8
# 2                         NaN    NaN           90.0     63.0     7.5
# 3                         NaN    NaN           90.0     73.0     6.9
# 4                         NaN    NaN           90.0     51.0     7.2
#
#    possessionLostCtrl                         ratingVersions  goalsPrevented
# 0                21.0    {'original': 7, 'alternative': 7.3}          0.1831
# 1                20.0  {'original': 6.8, 'alternative': 6.7}             NaN
# 2                 5.0  {'original': 7.5, 'alternative': 7.6}             NaN
# 3                 9.0  {'original': 6.9, 'alternative': 6.9}             NaN
# 4                 6.0  {'original': 7.2, 'alternative': 7.1}             NaN

# %%
df.drop('ratingVersions', axis=1, inplace=True)

# %%
df
# Out:
#                      name  shirtNumber jerseyNumber position  substitute  \
# 0         Paulo Gazzaniga           13           13        G       False
# 1               Yan Couto           20           20        M       False
# 2             Eric García           25           25        D       False
# 3             Daley Blind           17           17        D       False
# 4        Miguel Gutiérrez            3            3        D       False
# 5          Yangel Herrera           21           21        M       False
# 6            Aleix García           14           14        M       False
# 7        Viktor Tsygankov            8            8        M       False
# 8             Iván Martín           23           23        M       False
# 9                   Sávio           16           16        M       False
# 10                  Portu           24           24        M       False
# 11            Pablo Torre           18           18        M        True
# 12       Cristhian Stuani            7            7        F        True
# 13       Valery Fernández           11           11        D        True
# 14             Jhon Solís           22           22        M        True
# 15           Toni Fuidias           26           26        G        True
# 16         Arnau Martínez            4            4        D        True
# 17    Antal Yaakobishvili           35           35        D        True
# 18                 Juanpe           15           15        D        True
# 19           Borja García           10           10        M        True
# 20          Ricard Artero           36           36        M        True
# 21            Álex Remiro            1            1        G       False
# 22       Álvaro Odriozola            2            2        D       False
# 23          Igor Zubeldia            5            5        D       False
# 24            Jon Pacheco           20           20        D       False
# 25             Javi Galán           25           25        D       False
# 26        Sheraldo Becker           11           11        F       False
# 27       Beñat Turrientes           22           22        M       False
# 28       Martín Zubimendi            4            4        M       False
# 29        Mikel Oyarzabal           10           10        F       False
# 30           Brais Méndez           23           23        M       False
# 31            André Silva           21           21        F       False
# 32           Jon Aramburu           39           39        M        True
# 33           Mikel Merino            8            8        M        True
# 34      Ander Barrenetxea            7            7        F        True
# 35   Jon Ander Olasagasti           16           16        M        True
# 36             Umar Sadiq           19           19        F        True
# 37           Unai Marrero           13           13        G        True
# 38       Robin Le Normand           24           24        D        True
# 39     Jon Martin Vicente           36           36        D        True
# 40  Iñaki Rupérez Urtasun           41           41        D        True
# 41          Urko González           15           15        D        True
# 42       Jon Magunazelaia           28           28        M        True
# 43        Arsen Zakharyan           12           12        M        True
#
#     type captain  totalPass  accuratePass  totalLongBalls  accurateLongBalls  \
# 0   home     NaN       45.0          26.0            27.0                9.0
# 1   home     NaN       52.0          44.0             3.0                3.0
# 2   home     NaN       52.0          47.0             4.0                3.0
# 3   home     NaN       60.0          54.0             2.0                NaN
# 4   home     NaN       35.0          32.0             1.0                1.0
# 5   home     NaN       26.0          22.0             1.0                1.0
# 6   home    True       31.0          28.0             1.0                1.0
# 7   home     NaN       23.0          16.0             1.0                NaN
# 8   home     NaN       27.0          23.0             1.0                1.0
# 9   home     NaN       23.0          19.0             2.0                2.0
# 10  home     NaN        6.0           6.0             NaN                NaN
# 11  home     NaN        5.0           5.0             NaN                NaN
# 12  home     NaN        4.0           2.0             NaN                NaN
# 13  home     NaN        3.0           2.0             NaN                NaN
# 14  home     NaN       11.0          10.0             NaN                NaN
# 15  home     NaN        NaN           NaN             NaN                NaN
# 16  home     NaN        NaN           NaN             NaN                NaN
# 17  home     NaN        NaN           NaN             NaN                NaN
# 18  home     NaN        NaN           NaN             NaN                NaN
# 19  home     NaN        NaN           NaN             NaN                NaN
# 20  home     NaN        NaN           NaN             NaN                NaN
# 21  away     NaN       32.0          28.0             9.0                5.0
# 22  away     NaN        NaN           NaN             NaN                NaN
# 23  away     NaN       60.0          50.0             8.0                4.0
# 24  away     NaN       65.0          63.0             8.0                6.0
# 25  away     NaN       32.0          27.0             2.0                NaN
# 26  away     NaN       12.0           8.0             NaN                NaN
# 27  away     NaN       20.0          19.0             3.0                3.0
# 28  away     NaN       54.0          53.0             2.0                1.0
# 29  away    True       31.0          25.0             3.0                3.0
# 30  away     NaN       33.0          25.0             3.0                1.0
# 31  away     NaN       20.0          17.0             NaN                NaN
# 32  away     NaN       33.0          28.0             4.0                1.0
# 33  away     NaN       25.0          21.0             NaN                NaN
# 34  away     NaN        9.0           4.0             1.0                NaN
# 35  away     NaN        NaN           NaN             NaN                NaN
# 36  away     NaN        1.0           1.0             NaN                NaN
# 37  away     NaN        NaN           NaN             NaN                NaN
# 38  away     NaN        NaN           NaN             NaN                NaN
# 39  away     NaN        NaN           NaN             NaN                NaN
# 40  away     NaN        NaN           NaN             NaN                NaN
# 41  away     NaN        NaN           NaN             NaN                NaN
# 42  away     NaN        NaN           NaN             NaN                NaN
# 43  away     NaN        NaN           NaN             NaN                NaN
#
#     savedShotsFromInsideTheBox  saves  minutesPlayed  touches  rating  \
# 0                          1.0    2.0           90.0     51.0     7.0
# 1                          NaN    NaN           90.0     83.0     6.8
# 2                          NaN    NaN           90.0     63.0     7.5
# 3                          NaN    NaN           90.0     73.0     6.9
# 4                          NaN    NaN           90.0     51.0     7.2
# 5                          NaN    NaN           90.0     53.0     7.4
# 6                          NaN    NaN           80.0     44.0     7.0
# 7                          NaN    NaN           80.0     40.0     6.9
# 8                          NaN    NaN           70.0     32.0     6.8
# 9                          NaN    NaN           90.0     52.0     7.1
# 10                         NaN    NaN           70.0     11.0     6.6
# 11                         NaN    NaN           20.0      7.0     6.6
# 12                         NaN    NaN           20.0     11.0     6.7
# 13                         NaN    NaN           10.0      8.0     6.7
# 14                         NaN    NaN           10.0     14.0     6.9
# 15                         NaN    NaN            NaN      NaN     NaN
# 16                         NaN    NaN            NaN      NaN     NaN
# 17                         NaN    NaN            NaN      NaN     NaN
# 18                         NaN    NaN            NaN      NaN     NaN
# 19                         NaN    NaN            NaN      NaN     NaN
# 20                         NaN    NaN            NaN      NaN     NaN
# 21                         2.0    3.0           90.0     37.0     7.3
# 22                         NaN    NaN            3.0      1.0     NaN
# 23                         NaN    NaN           90.0     66.0     7.3
# 24                         NaN    NaN           90.0     74.0     7.3
# 25                         NaN    NaN           90.0     62.0     7.1
# 26                         NaN    NaN           52.0     19.0     6.5
# 27                         NaN    NaN           52.0     27.0     6.7
# 28                         NaN    NaN           90.0     66.0     6.7
# 29                         NaN    NaN           89.0     45.0     6.9
# 30                         NaN    NaN           87.0     50.0     7.1
# 31                         NaN    NaN           87.0     43.0     6.8
# 32                         NaN    NaN           87.0     57.0     6.9
# 33                         NaN    NaN           38.0     36.0     6.7
# 34                         NaN    NaN           38.0     33.0     7.4
# 35                         NaN    NaN           10.0      NaN     6.5
# 36                         NaN    NaN           10.0      2.0     6.5
# 37                         NaN    NaN            NaN      NaN     NaN
# 38                         NaN    NaN            NaN      NaN     NaN
# 39                         NaN    NaN            NaN      NaN     NaN
# 40                         NaN    NaN            NaN      NaN     NaN
# 41                         NaN    NaN            NaN      NaN     NaN
# 42                         NaN    NaN            NaN      NaN     NaN
# 43                         NaN    NaN            NaN      NaN     NaN
#
#     possessionLostCtrl  goalsPrevented
# 0                 21.0          0.1831
# 1                 20.0             NaN
# 2                  5.0             NaN
# 3                  9.0             NaN
# 4                  6.0             NaN
# 5                  9.0             NaN
# 6                  5.0             NaN
# 7                 12.0             NaN
# 8                  4.0             NaN
# 9                 18.0             NaN
# 10                 1.0             NaN
# 11                 1.0             NaN
# 12                 4.0             NaN
# 13                 3.0             NaN
# 14                 1.0             NaN
# 15                 NaN             NaN
# 16                 NaN             NaN
# 17                 NaN             NaN
# 18                 NaN             NaN
# 19                 NaN             NaN
# 20                 NaN             NaN
# 21                 4.0          0.4932
# 22                 NaN             NaN
# 23                10.0             NaN
# 24                 5.0             NaN
# 25                12.0             NaN
# 26                 9.0             NaN
# 27                 4.0             NaN
# 28                 5.0             NaN
# 29                12.0             NaN
# 30                16.0             NaN
# 31                13.0             NaN
# 32                13.0             NaN
# 33                 7.0             NaN
# 34                13.0             NaN
# 35                 NaN             NaN
# 36                 NaN             NaN
# 37                 NaN             NaN
# 38                 NaN             NaN
# 39                 NaN             NaN
# 40                 NaN             NaN
# 41                 NaN             NaN
# 42                 NaN             NaN
# 43                 NaN             NaN
